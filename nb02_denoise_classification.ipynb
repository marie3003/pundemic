# %% [markdown]
# # Data cleaning and classification

# %%
# Package import and data directory
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt
import numpy as np
import qiime2 as q2
import seaborn as sns

# %matplotlib inline

data_dir = 'data'
data_dir_pre = 'data/preprocessing'

# %% [markdown]
# ##  Get data

# %%
# Data and metadata import
if not os.path.exists('data/pundemic_metadata.tsv'):
    ! wget -O $data_dir/pundemic_metadata.tsv https://polybox.ethz.ch/index.php/s/7LxWSbaw2q37yof/download

if not os.path.exists('data/pundemic_forward_reads.qza'):
    ! wget -O $data_dir/pundemic_forward_reads.qza https://polybox.ethz.ch/index.php/s/o8HqHJqvuf9e2on/download

# %%
meta_df = pd.read_csv('data/pundemic_metadata.tsv', sep='\t', index_col=0)

# %% [markdown]
# ## Metadata df overview

# %%
meta_df.head()
# Out:
#             patient_id age     sex              ethnicity continent  \
# id
# SRR10505051       1048  36  female              Caucasian    Europe
# SRR10505052       1048  36  female              Caucasian    Europe
# SRR10505053       1045  29    male              Caucasian    Europe
# SRR10505054       1045  29    male              Caucasian    Europe
# SRR10505055       1044  34    male  Indian Subcontinental    Europe
#
#                  country  region    city group disease_subgroup  \
# id
# SRR10505051  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505052  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505053  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505054  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505055  Switzerland  Zurich  Zurich  Puns          Placebo
#
#             blinded_clinical_response  puns_per_hour_pre_treatment  \
# id
# SRR10505051                        NR                          9.0
# SRR10505052                        NR                          9.0
# SRR10505053                       Res                          6.0
# SRR10505054                       Res                          6.0
# SRR10505055                       NaN                          4.0
#
#              puns_per_hour_post_treatment      time_point
# id
# SRR10505051                           8.0  post-treatment
# SRR10505052                           8.0   pre-treatment
# SRR10505053                           0.0   pre-treatment
# SRR10505054                           0.0  post-treatment
# SRR10505055                           NaN   pre-treatment

# %%
# We have 3 groups, placebo FMT and donor
meta_df['disease_subgroup'].unique()
# Out:
# array(['Placebo', 'FMT', 'donor'], dtype=object)

# %%
# Creating DFs of our different populations for potential later use
patient_df = meta_df[(meta_df['disease_subgroup'] == "placebo") | (meta_df['disease_subgroup'] == "FMT")]
patient_df.to_csv(f'{data_dir}/patient_df', sep = '\t')

# %%
donor_df = meta_df[(meta_df['disease_subgroup'] == "donor")]
donor_df.to_csv(f'{data_dir}/donor_df', sep = '\t')

# %%
meta_df[(meta_df['time_point'] == "pre-treatment") | (meta_df['time_point'] == "post-treatment")]
# Out:
#             patient_id      age     sex              ethnicity continent  \
# id
# SRR10505051       1048       36  female              Caucasian    Europe
# SRR10505052       1048       36  female              Caucasian    Europe
# SRR10505053       1045       29    male              Caucasian    Europe
# SRR10505054       1045       29    male              Caucasian    Europe
# SRR10505055       1044       34    male  Indian Subcontinental    Europe
# ...                ...      ...     ...                    ...       ...
# SRR10505141       1001       57  female              Caucasian    Europe
# SRR10505142       1001       57  female              Caucasian    Europe
# SRR10505153       2225       34    male              Caucasian    Europe
# SRR10505154       1024  Unknown  female              Caucasian    Europe
# SRR10505155       1005       30  female              Caucasian    Europe
#
#                  country  region    city group disease_subgroup  \
# id
# SRR10505051  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505052  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505053  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505054  Switzerland  Zurich  Zurich  Puns          Placebo
# SRR10505055  Switzerland  Zurich  Zurich  Puns          Placebo
# ...                  ...     ...     ...   ...              ...
# SRR10505141  Switzerland  Zurich  Zurich  Puns              FMT
# SRR10505142  Switzerland  Zurich  Zurich  Puns              FMT
# SRR10505153  Switzerland  Zurich  Zurich  Puns              FMT
# SRR10505154  Switzerland  Zurich  Zurich  Puns              FMT
# SRR10505155  Switzerland  Zurich  Zurich  Puns          Placebo
#
#             blinded_clinical_response  puns_per_hour_pre_treatment  \
# id
# SRR10505051                        NR                          9.0
# SRR10505052                        NR                          9.0
# SRR10505053                       Res                          6.0
# SRR10505054                       Res                          6.0
# SRR10505055                       NaN                          4.0
# ...                               ...                          ...
# SRR10505141                       Res                          7.0
# SRR10505142                       Res                          7.0
# SRR10505153                        NR                          6.0
# SRR10505154                       Res                          8.0
# SRR10505155                        NR                          8.0
#
#              puns_per_hour_post_treatment      time_point
# id
# SRR10505051                           8.0  post-treatment
# SRR10505052                           8.0   pre-treatment
# SRR10505053                           0.0   pre-treatment
# SRR10505054                           0.0  post-treatment
# SRR10505055                           NaN   pre-treatment
# ...                                   ...             ...
# SRR10505141                           2.0   pre-treatment
# SRR10505142                           2.0  post-treatment
# SRR10505153                           5.0   pre-treatment
# SRR10505154                           0.0  post-treatment
# SRR10505155                           8.0   pre-treatment
#
# [87 rows x 14 columns]

# %% [markdown]
# From initial exploration, there are 105 samples from different groups:
#
# - Donor of the FMT treatment group
# - Placebo treatment
# - FMT treatment
#
# And we also have different timepoints of data colleciton, pre and post treatment.

# %% [markdown]
# # Sequence Import

# %%
! qiime tools peek $data_dir/pundemic_forward_reads.qza
# Out:
# UUID:        15b104e4-bd22-4469-92ac-e08f76767733
# Type:        SampleData[SequencesWithQuality]
# Data format: SingleLanePerSampleSingleEndFastqDirFmt

# %%
! qiime demux summarize \
    --i-data $data_dir/pundemic_forward_reads.qza \
    --o-visualization $data_dir_pre/pundemic_forward_reads.qzv
# Out:
# Saved Visualization to: data/preprocessing/pundemic_forward_reads.qzv

# %%
Visualization.load(f"{data_dir_pre}/pundemic_forward_reads.qzv")
# Out:
# <visualization: Visualization uuid: ba187720-d548-42ca-ba4e-f34bd49e3b09>

# %% [markdown]
# From this summary, we find that our samples have around a 10 fold spread in terms of sample reads, with the median around 44,000. We have been informed by the TAs there were primers still in this dataset, which we remove in the following cells:

# %% [markdown]
# # Cut primer sequences in data

# %%
# Quality filtering
# no cutoff to keep longer reads for our ITS data
! qiime quality-filter q-score \
    --i-demux $data_dir/pundemic_forward_reads.qza \
    --p-min-quality 15 \
    --p-min-length-fraction 0 \
    --p-quality-window 3 \
    --o-filtered-sequences $data_dir_pre/pundemic_forward_reads_QCfiltered.qza \
    --o-filter-stats $data_dir_pre/pundemic_forward_reads_QCfiltered_stats.qza
# Out:
# ^C
#
# Aborted!

# %%
! qiime demux summarize \
    --i-data $data_dir_pre/pundemic_forward_reads_QCfiltered.qza  \
    --o-visualization $data_dir_pre/pundemic_forward_reads_QCfiltered.qzv
# Out:
# Saved Visualization to: data/preprocessing/pundemic_forward_reads_QCfiltered.qzv

# %%
Visualization.load(f"{data_dir_pre}/pundemic_forward_reads_QCfiltered.qzv")
# Out:
# <visualization: Visualization uuid: 2f8aefca-ac27-48b1-8aa9-f1edfea53dfd>

# %%
# Trim forward primer

! qiime cutadapt trim-single \
  --i-demultiplexed-sequences $data_dir_pre/pundemic_forward_reads_QCfiltered.qza \
  --p-front CTTGGTCATTTAGAGGAAGTAA \
  --p-overlap 8 \
  --p-error-rate 0.2 \
  --p-discard-untrimmed \
  --verbose \
  --o-trimmed-sequences $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered.qza | tee $data_dir_pre/cutadapt_results.txt
# Out:
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505051_0_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505051_0_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        37,345 reads @  15.1 µs/read;   3.97 M reads/minute
# Finished in 0.567 s (15.183 µs/read; 3.95 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  37,345
# Reads with adapters:                    37,290 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        37,290 (99.9%)
#
# Total basepairs processed:     7,533,419 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,717,839 bp (89.2%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 37290 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	2	0.0	2	0 1 1
# 14	2	0.0	2	0 2
# 15	2	0.0	3	0 2
# 16	5	0.0	3	0 3 0 2
# 17	4	0.0	3	0 2 1 1
# 18	11	0.0	3	4 3 1 1 2
# 19	18	0.0	3	0 0 2 16
# 20	196	0.0	4	2 14 147 31 2
# 21	14459	0.0	4	26 11712 2660 51 10
# 22	22541	0.0	4	21387 971 145 25 13
# 23	49	0.0	4	3 40 6
# 36	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505052_1_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505052_1_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        16,777 reads @  16.4 µs/read;   3.66 M reads/minute
# Finished in 0.277 s (16.512 µs/read; 3.63 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  16,777
# Reads with adapters:                    16,611 (99.0%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        16,611 (99.0%)
#
# Total basepairs processed:     3,204,520 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,808,778 bp (87.7%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 16611 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	1	0.0	2	0 0 1
# 14	1	0.0	2	0 1
# 16	1	0.0	3	0 0 1
# 19	5	0.0	3	0 0 3 2
# 20	54	0.0	4	0 3 39 12
# 21	5913	0.0	4	8 4583 1275 45 2
# 22	10574	0.0	4	8616 1476 450 26 6
# 23	59	0.0	4	5 11 36 3 4
# 24	1	0.0	4	0 0 0 1
# 44	1	0.0	4	0 1
# 128	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505053_2_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505053_2_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        91,252 reads @  19.0 µs/read;   3.16 M reads/minute
# Finished in 1.733 s (18.989 µs/read; 3.16 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  91,252
# Reads with adapters:                    91,086 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        91,086 (99.8%)
#
# Total basepairs processed:    20,506,074 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     18,483,550 bp (90.1%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 91086 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	2	0.1	2	1 1
# 11	2	0.0	2	2
# 13	8	0.0	2	5 3
# 14	4	0.0	2	0 4
# 15	4	0.0	3	2 2
# 16	3	0.0	3	0 1 1 1
# 17	14	0.0	3	6 4 2 2
# 18	15	0.0	3	4 1 2 5 3
# 19	31	0.0	3	1 3 9 17 1
# 20	257	0.0	4	5 23 190 38 1
# 21	16802	0.0	4	71 13986 2655 82 8
# 22	73796	0.0	4	68728 3784 1158 94 32
# 23	144	0.0	4	18 103 20 1 2
# 24	3	0.0	4	0 0 3
# 29	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505054_3_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505054_3_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        11,337 reads @  16.1 µs/read;   3.74 M reads/minute
# Finished in 0.184 s (16.231 µs/read; 3.70 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  11,337
# Reads with adapters:                    11,311 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        11,311 (99.8%)
#
# Total basepairs processed:     1,681,451 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      1,438,818 bp (85.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 11311 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 15	1	0.0	3	0 0 1
# 16	1	0.0	3	0 0 0 1
# 17	1	0.0	3	0 1
# 18	2	0.0	3	0 0 1 1
# 19	15	0.0	3	0 1 1 12 1
# 20	129	0.0	4	0 3 81 43 2
# 21	10374	0.0	4	0 7015 3309 45 5
# 22	787	0.0	4	572 119 76 16 4
# 61	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505055_4_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505055_4_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        22,858 reads @  17.3 µs/read;   3.46 M reads/minute
# Finished in 0.398 s (17.424 µs/read; 3.44 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  22,858
# Reads with adapters:                    22,794 (99.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        22,794 (99.7%)
#
# Total basepairs processed:     3,401,299 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,909,737 bp (85.5%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 22794 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 16	1	0.0	3	0 1
# 17	6	0.0	3	0 3 2 1
# 18	9	0.0	3	0 1 0 6 2
# 19	21	0.0	3	0 2 1 11 7
# 20	210	0.0	4	0 7 119 79 5
# 21	19810	0.0	4	0 13909 5787 111 3
# 22	2714	0.0	4	2044 507 134 24 5
# 23	21	0.0	4	0 1 17 3
# 61	1	0.0	4	0 1
# 64	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505056_5_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505056_5_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       159,754 reads @  15.0 µs/read;   4.00 M reads/minute
# Finished in 2.396 s (15.001 µs/read; 4.00 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 159,754
# Reads with adapters:                   159,577 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       159,577 (99.9%)
#
# Total basepairs processed:    37,573,749 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     34,033,931 bp (90.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 159577 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	4	0.2	2	3 1
# 12	2	0.0	2	0 0 2
# 13	1	0.0	2	1
# 14	7	0.0	2	5 2
# 15	9	0.0	3	0 9
# 16	7	0.0	3	0 6 0 1
# 17	24	0.0	3	2 5 12 5
# 18	20	0.0	3	7 7 1 5
# 19	59	0.0	3	8 8 14 28 1
# 20	153	0.0	4	9 12 122 9 1
# 21	6229	0.0	4	74 5344 757 47 7
# 22	152727	0.0	4	142852 7435 2265 128 47
# 23	332	0.0	4	45 211 71 3 2
# 24	1	0.0	4	0 0 0 0 1
# 44	2	0.0	4	2
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505057_6_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505057_6_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        19,972 reads @  18.5 µs/read;   3.25 M reads/minute
# Finished in 0.371 s (18.590 µs/read; 3.23 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  19,972
# Reads with adapters:                    19,920 (99.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        19,920 (99.7%)
#
# Total basepairs processed:     3,679,316 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      3,245,578 bp (88.2%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 19920 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 14	1	0.0	2	0 0 1
# 15	3	0.0	3	2 0 1
# 16	1	0.0	3	0 0 1
# 17	8	0.0	3	2 5 1
# 18	11	0.0	3	0 2 3 4 2
# 19	59	0.0	3	0 0 10 34 15
# 20	1018	0.0	4	0 19 678 315 6
# 21	10823	0.0	4	26 7554 3157 79 7
# 22	7983	0.0	4	6977 695 259 47 5
# 23	12	0.0	4	1 6 3 0 2
# 24	1	0.0	4	0 0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505058_7_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505058_7_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        58,741 reads @  15.7 µs/read;   3.83 M reads/minute
# Finished in 0.923 s (15.706 µs/read; 3.82 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  58,741
# Reads with adapters:                    58,671 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        58,671 (99.9%)
#
# Total basepairs processed:    13,002,387 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     11,712,852 bp (90.1%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 58671 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	2	0.0	2	1 1
# 14	1	0.0	2	0 1
# 16	6	0.0	3	0 3 3
# 17	5	0.0	3	0 1 4
# 18	20	0.0	3	0 7 1 8 4
# 19	46	0.0	3	0 0 7 38 1
# 20	827	0.0	4	3 33 694 94 3
# 21	11935	0.0	4	97 10430 1355 44 9
# 22	45727	0.0	4	42957 2419 306 27 18
# 23	99	0.0	4	12 63 23 1
# 24	3	0.0	4	0 0 3
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505059_8_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505059_8_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        38,184 reads @  16.1 µs/read;   3.72 M reads/minute
# Finished in 0.618 s (16.190 µs/read; 3.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  38,184
# Reads with adapters:                    38,078 (99.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        38,078 (99.7%)
#
# Total basepairs processed:     6,887,855 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,051,731 bp (87.9%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 38078 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	2	0.0	2	0 1 1
# 14	1	0.0	2	0 0 1
# 15	1	0.0	3	0 0 0 1
# 16	3	0.0	3	0 2 1
# 17	7	0.0	3	0 4 1 2
# 18	9	0.0	3	3 1 1 1 3
# 19	30	0.0	3	0 3 4 15 8
# 20	259	0.0	4	4 15 166 58 16
# 21	20457	0.0	4	9 15019 5267 140 22
# 22	17222	0.0	4	13079 2786 1243 62 52
# 23	84	0.0	4	2 23 35 10 14
# 24	1	0.0	4	0 0 1
# 32	2	0.0	4	0 2
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505060_9_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505060_9_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        17,632 reads @  16.0 µs/read;   3.75 M reads/minute
# Finished in 0.285 s (16.146 µs/read; 3.72 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  17,632
# Reads with adapters:                    17,596 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        17,596 (99.8%)
#
# Total basepairs processed:     2,588,326 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,209,659 bp (85.4%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 17596 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 15	1	0.0	3	0 1
# 16	3	0.0	3	0 1 1 1
# 17	2	0.0	3	0 2
# 18	3	0.0	3	0 0 0 0 3
# 19	13	0.0	3	0 3 2 8
# 20	185	0.0	4	0 5 130 49 1
# 21	14281	0.0	4	0 10821 3383 70 7
# 22	3006	0.0	4	1724 828 415 30 9
# 23	98	0.0	4	0 1 90 4 3
# 27	1	0.0	4	0 1
# 30	1	0.0	4	0 0 1
# 40	1	0.0	4	0 1
# 52	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505061_10_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505061_10_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        75,925 reads @  17.6 µs/read;   3.41 M reads/minute
# Finished in 1.339 s (17.638 µs/read; 3.40 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  75,925
# Reads with adapters:                    75,787 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        75,787 (99.8%)
#
# Total basepairs processed:    16,007,198 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     14,323,031 bp (89.5%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 75787 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	1	0.0	2	0 0 1
# 13	1	0.0	2	1
# 16	3	0.0	3	1 2
# 17	4	0.0	3	0 3 1
# 18	2	0.0	3	0 0 0 1 1
# 19	7	0.0	3	0 0 4 2 1
# 20	157	0.0	4	1 10 113 29 4
# 21	4999	0.0	4	83 3762 830 300 24
# 22	70529	0.0	4	49205 15212 5345 669 98
# 23	81	0.0	4	4 36 24 12 5
# 25	3	0.0	4	0 0 0 0 3
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505062_11_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505062_11_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        41,624 reads @  19.3 µs/read;   3.10 M reads/minute
# Finished in 0.808 s (19.418 µs/read; 3.09 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  41,624
# Reads with adapters:                    41,573 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        41,573 (99.9%)
#
# Total basepairs processed:     8,501,826 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      7,594,487 bp (89.3%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 41573 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 14	1	0.0	2	0 1
# 16	5	0.0	3	0 1 3 1
# 17	6	0.0	3	0 1 1 4
# 18	9	0.0	3	4 1 1 2 1
# 19	25	0.0	3	0 4 3 17 1
# 20	186	0.0	4	2 12 142 27 3
# 21	16067	0.0	4	14 13430 2564 50 9
# 22	25221	0.0	4	24012 1054 124 20 11
# 23	53	0.0	4	8 41 4
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505063_12_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505063_12_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        89,119 reads @  15.1 µs/read;   3.98 M reads/minute
# Finished in 1.345 s (15.096 µs/read; 3.97 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  89,119
# Reads with adapters:                    89,021 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        89,021 (99.9%)
#
# Total basepairs processed:    20,806,909 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     18,844,431 bp (90.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 89021 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 14	9	0.0	2	4 3 2
# 15	6	0.0	3	1 4 1
# 16	16	0.0	3	9 4 3
# 17	6	0.0	3	3 3
# 18	24	0.0	3	0 8 2 9 5
# 19	61	0.0	3	0 1 25 35
# 20	818	0.0	4	4 64 682 64 4
# 21	12751	0.0	4	185 11606 880 74 6
# 22	75183	0.0	4	72121 2593 378 63 28
# 23	140	0.0	4	22 109 8 1
# 24	4	0.0	4	2 1 1
# 29	1	0.0	4	0 1
# 32	2	0.0	4	0 0 0 2
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505064_13_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505064_13_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:03       250,877 reads @  13.8 µs/read;   4.33 M reads/minute
# Finished in 3.477 s (13.859 µs/read; 4.33 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 250,877
# Reads with adapters:                   250,606 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       250,606 (99.9%)
#
# Total basepairs processed:    59,151,576 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     53,602,005 bp (90.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 250606 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	1	1.0	1	1
# 10	2	0.2	2	2
# 12	1	0.0	2	0 0 1
# 13	5	0.0	2	0 3 2
# 14	22	0.0	2	0 11 11
# 15	6	0.0	3	0 1 1 4
# 16	15	0.0	3	0 10 2 3
# 17	21	0.0	3	6 6 6 3
# 18	39	0.0	3	19 8 2 2 8
# 19	73	0.0	3	8 6 16 43
# 20	323	0.0	4	18 25 238 30 12
# 21	17009	0.0	4	112 13453 3356 83 5
# 22	232665	0.0	4	220815 10340 1303 148 59
# 23	423	0.0	4	74 325 21 3
# 24	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505065_14_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505065_14_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:03       213,050 reads @  17.9 µs/read;   3.36 M reads/minute
# Finished in 3.811 s (17.886 µs/read; 3.35 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 213,050
# Reads with adapters:                   212,767 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       212,767 (99.9%)
#
# Total basepairs processed:    48,590,185 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     43,856,669 bp (90.3%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 212767 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	2	0.8	1	1 1
# 12	1	0.0	2	0 0 1
# 13	4	0.0	2	0 3 1
# 14	8	0.0	2	0 2 6
# 15	12	0.0	3	3 5 4
# 16	10	0.0	3	0 8 2
# 17	30	0.0	3	6 7 8 9
# 18	28	0.0	3	10 6 8 3 1
# 19	62	0.0	3	5 3 11 28 15
# 20	211	0.0	4	5 14 85 82 25
# 21	4410	0.0	4	39 2436 1685 235 15
# 22	205797	0.0	4	77901 102196 24910 626 164
# 23	2182	0.0	4	34 155 1895 90 8
# 24	10	0.0	4	0 0 2 8
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505066_15_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505066_15_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       136,392 reads @  16.5 µs/read;   3.63 M reads/minute
# Finished in 2.254 s (16.529 µs/read; 3.63 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 136,392
# Reads with adapters:                   136,186 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       136,186 (99.8%)
#
# Total basepairs processed:    32,557,742 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     29,531,937 bp (90.7%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 136186 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 9	2	0.5	1	2
# 11	1	0.0	2	0 1
# 13	5	0.0	2	0 3 2
# 15	5	0.0	3	0 4 1
# 16	17	0.0	3	4 4 4 5
# 17	10	0.0	3	1 2 4 3
# 18	17	0.0	3	0 7 2 4 4
# 19	58	0.0	3	2 3 17 35 1
# 20	558	0.0	4	4 44 367 43 100
# 21	12203	0.0	4	234 8781 630 2478 80
# 22	122633	0.0	4	89267 3988 28458 829 91
# 23	671	0.0	4	31 116 458 59 7
# 24	2	0.0	4	0 0 1 1
# 25	1	0.0	4	1
# 26	2	0.0	4	0 0 2
# 27	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505067_16_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505067_16_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       145,127 reads @  19.0 µs/read;   3.16 M reads/minute
# Finished in 2.761 s (19.025 µs/read; 3.15 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 145,127
# Reads with adapters:                   144,869 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       144,869 (99.8%)
#
# Total basepairs processed:    32,248,581 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     28,977,648 bp (89.9%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 144869 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	2	0 1
# 13	2	0.0	2	0 0 2
# 14	1	0.0	2	0 0 1
# 15	4	0.0	3	0 1 1 2
# 16	7	0.0	3	0 2 3 2
# 17	12	0.0	3	0 5 3 4
# 18	12	0.0	3	0 0 6 3 3
# 19	30	0.0	3	0 1 11 18
# 20	274	0.0	4	0 14 160 57 43
# 21	24688	0.0	4	0 19182 4565 887 54
# 22	64481	0.0	4	2546 2590 56953 2298 94
# 23	55265	0.0	4	1 83 53594 1522 65
# 24	91	0.0	4	0 0 13 77 1
# 55	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505068_17_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505068_17_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        74,745 reads @  14.6 µs/read;   4.10 M reads/minute
# Finished in 1.096 s (14.668 µs/read; 4.09 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  74,745
# Reads with adapters:                    74,665 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        74,665 (99.9%)
#
# Total basepairs processed:    16,571,978 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     14,930,240 bp (90.1%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 74665 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 8	2	1.1	1	0 2
# 11	2	0.0	2	2
# 14	4	0.0	2	1 3
# 15	3	0.0	3	0 3
# 16	14	0.0	3	3 10 1
# 17	9	0.0	3	2 3 1 3
# 18	26	0.0	3	7 6 4 8 1
# 19	35	0.0	3	1 3 10 19 2
# 20	217	0.0	4	2 11 162 35 7
# 21	15894	0.0	4	32 12966 2811 78 7
# 22	58248	0.0	4	55268 2168 754 45 13
# 23	207	0.0	4	12 82 111 1 1
# 24	2	0.0	4	0 0 1 1
# 25	2	0.0	4	0 0 0 2
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505069_18_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505069_18_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:07       443,283 reads @  15.8 µs/read;   3.80 M reads/minute
# Finished in 7.004 s (15.801 µs/read; 3.80 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 443,283
# Reads with adapters:                   442,660 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       442,660 (99.9%)
#
# Total basepairs processed:   104,623,116 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     94,831,610 bp (90.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 442660 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	5	0.4	2	5
# 12	5	0.0	2	3 1 1
# 13	9	0.0	2	3 6
# 14	18	0.0	2	7 10 1
# 15	22	0.0	3	8 11 3
# 16	41	0.0	3	20 11 6 4
# 17	64	0.0	3	10 29 21 4
# 18	131	0.0	3	8 65 10 40 8
# 19	300	0.0	3	5 9 98 171 17
# 20	4100	0.0	4	30 298 3420 284 68
# 21	63644	0.0	4	1025 57094 4780 675 70
# 22	373551	0.0	4	352584 15676 4750 346 195
# 23	724	0.0	4	84 548 43 37 12
# 24	27	0.0	4	4 1 12 4 6
# 25	8	0.0	4	1 1 0 3 3
# 26	5	0.0	4	2 0 0 0 3
# 29	1	0.0	4	1
# 30	2	0.0	4	0 0 0 2
# 31	2	0.0	4	0 0 2
# 34	1	0.0	4	1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505070_19_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505070_19_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        14,845 reads @  15.8 µs/read;   3.81 M reads/minute
# Finished in 0.236 s (15.889 µs/read; 3.78 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  14,845
# Reads with adapters:                    14,811 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        14,811 (99.8%)
#
# Total basepairs processed:     2,222,902 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      1,905,755 bp (85.7%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 14811 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 17	5	0.0	3	0 1 2 2
# 18	5	0.0	3	0 0 1 2 2
# 19	12	0.0	3	0 0 2 5 5
# 20	161	0.0	4	0 6 100 52 3
# 21	13385	0.0	4	1 9430 3872 75 7
# 22	1239	0.0	4	1083 91 48 14 3
# 23	4	0.0	4	0 3 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505071_20_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505071_20_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        32,574 reads @  18.7 µs/read;   3.21 M reads/minute
# Finished in 0.611 s (18.747 µs/read; 3.20 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  32,574
# Reads with adapters:                    32,518 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        32,518 (99.8%)
#
# Total basepairs processed:     6,481,731 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,770,521 bp (89.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 32518 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	1	0.0	2	0 0 1
# 13	7	0.0	2	5 2
# 15	1	0.0	3	0 1
# 16	4	0.0	3	0 1 2 1
# 17	11	0.0	3	5 4 2
# 18	7	0.0	3	0 0 0 4 3
# 19	16	0.0	3	2 1 1 10 2
# 20	153	0.0	4	4 7 107 35
# 21	12229	0.0	4	10 9192 2965 56 6
# 22	20021	0.0	4	18566 1274 153 21 7
# 23	67	0.0	4	12 34 21
# 50	1	0.0	4	0 0 0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505072_21_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505072_21_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        36,529 reads @  16.2 µs/read;   3.70 M reads/minute
# Finished in 0.595 s (16.294 µs/read; 3.68 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  36,529
# Reads with adapters:                    36,393 (99.6%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        36,393 (99.6%)
#
# Total basepairs processed:     7,169,429 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,361,000 bp (88.7%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 36393 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	1	0.0	2	0 0 1
# 12	1	0.0	2	0 0 1
# 14	4	0.0	2	0 2 2
# 15	1	0.0	3	0 1
# 16	4	0.0	3	2 1 1
# 17	10	0.0	3	2 3 5
# 18	10	0.0	3	1 2 2 3 2
# 19	40	0.0	3	0 1 9 27 3
# 20	862	0.0	4	3 43 685 121 10
# 21	10869	0.0	4	63 9008 1653 129 16
# 22	24550	0.0	4	20604 3475 386 60 25
# 23	39	0.0	4	8 24 5 2
# 24	2	0.0	4	0 0 2
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505051_0_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505051_0_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505052_1_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505052_1_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505053_2_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505053_2_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505054_3_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505054_3_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505055_4_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505055_4_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505056_5_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505056_5_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505057_6_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505057_6_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505058_7_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505058_7_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505059_8_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505059_8_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505060_9_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505060_9_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505061_10_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505061_10_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505062_11_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505062_11_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505063_12_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505063_12_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505064_13_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505064_13_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505065_14_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505065_14_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505066_15_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505066_15_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505067_16_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505067_16_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505068_17_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505068_17_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505069_18_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505069_18_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505070_19_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505070_19_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505071_20_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505071_20_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505072_21_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505072_21_L001_R1_001.fastq.gz
#
#
# Command: This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505073_22_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505073_22_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        26,229 reads @  17.7 µs/read;   3.38 M reads/minute
# Finished in 0.467 s (17.818 µs/read; 3.37 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  26,229
# Reads with adapters:                    26,168 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        26,168 (99.8%)
#
# Total basepairs processed:     4,077,801 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      3,512,687 bp (86.1%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 26168 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	2	0 0 1
# 15	1	0.0	3	0 1
# 16	4	0.0	3	0 1 2 1
# 17	6	0.0	3	0 2 4
# 18	7	0.0	3	2 0 0 2 3
# 19	21	0.0	3	0 2 2 13 4
# 20	242	0.0	4	0 5 150 82 5
# 21	20357	0.0	4	5 14970 5237 139 6
# 22	5393	0.0	4	2914 1546 864 50 19
# 23	134	0.0	4	0 10 119 4 1
# 24	1	0.0	4	0 0 0 1
# 64	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505074_23_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505074_23_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        28,394 reads @  17.1 µs/read;   3.51 M reads/minute
# Finished in 0.488 s (17.187 µs/read; 3.49 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  28,394
# Reads with adapters:                    28,336 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        28,336 (99.8%)
#
# Total basepairs processed:     4,815,636 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      4,198,760 bp (87.2%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 28336 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	1	0.0	2	0 0 1
# 16	1	0.0	3	0 1
# 17	6	0.0	3	0 4 2
# 18	11	0.0	3	0 1 2 7 1
# 19	10	0.0	3	0 1 1 8
# 20	158	0.0	4	0 17 115 22 4
# 21	16124	0.0	4	2 13228 2816 65 13
# 22	11919	0.0	4	9524 1428 895 37 35
# 23	104	0.0	4	0 14 82 7 1
# 24	1	0.0	4	0 0 0 1
# 55	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505075_24_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505075_24_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        33,983 reads @  18.9 µs/read;   3.17 M reads/minute
# Finished in 0.645 s (18.977 µs/read; 3.16 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  33,983
# Reads with adapters:                    33,832 (99.6%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        33,832 (99.6%)
#
# Total basepairs processed:     6,094,487 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,339,819 bp (87.6%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 33832 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	2	1
# 16	4	0.0	3	0 1 1 2
# 17	4	0.0	3	0 1 2 1
# 18	12	0.0	3	3 1 2 3 3
# 19	17	0.0	3	0 0 1 15 1
# 20	225	0.0	4	0 10 161 52 2
# 21	19705	0.0	4	9 15682 3886 113 15
# 22	13735	0.0	4	10776 2107 798 41 13
# 23	128	0.0	4	2 32 90 4
# 48	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505076_25_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505076_25_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        66,531 reads @  21.9 µs/read;   2.74 M reads/minute
# Finished in 1.462 s (21.970 µs/read; 2.73 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  66,531
# Reads with adapters:                    66,444 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        66,444 (99.9%)
#
# Total basepairs processed:    14,673,184 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     13,204,376 bp (90.0%)
#
# === Adapter 1 ===
#
# ...
# 22	14980	0.0	4	5623 4507 4443 323 84
# 23	74	0.0	4	2 18 26 18 10
# 24	9	0.0	4	0 0 0 9
# 32	1	0.0	4	0 1
# 33	2	0.0	4	0 0 1 1
# 34	1	0.0	4	0 0 0 1
# 37	1	0.0	4	0 0 1
# 44	1	0.0	4	0 0 1
# 58	1	0.0	4	0 1
# 66	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505150_99_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505150_99_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        95,401 reads @  15.8 µs/read;   3.80 M reads/minute
# Finished in 1.508 s (15.803 µs/read; 3.80 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  95,401
# Reads with adapters:                    93,086 (97.6%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        93,086 (97.6%)
#
# Total basepairs processed:    14,318,231 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     12,192,071 bp (85.2%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 93086 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	2	0 0 1
# 13	1	0.0	2	0 1
# 14	4	0.0	2	0 1 3
# 15	4	0.0	3	1 2 1
# 16	21	0.0	3	0 10 9 2
# 17	43	0.0	3	0 23 14 6
# 18	38	0.0	3	1 5 5 12 15
# 19	112	0.0	3	0 9 14 74 15
# 20	1482	0.0	4	0 80 919 470 13
# 21	87761	0.0	4	0 61753 25455 513 40
# 22	3588	0.0	4	2531 654 298 86 19
# 23	17	0.0	4	2 6 2 1 6
# 32	1	0.0	4	0 1
# 44	1	0.0	4	0 1
# 50	1	0.0	4	0 1
# 52	1	0.0	4	0 0 1
# 57	1	0.0	4	0 0 1
# 61	6	0.0	4	0 4 1 1
# 66	1	0.0	4	0 0 0 1
# 73	1	0.0	4	0 1
# 74	1	0.0	4	0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505151_100_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505151_100_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       130,789 reads @  19.4 µs/read;   3.10 M reads/minute
# Finished in 2.535 s (19.380 µs/read; 3.10 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 130,789
# Reads with adapters:                   130,504 (99.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       130,504 (99.8%)
#
# Total basepairs processed:    29,192,624 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     26,270,753 bp (90.0%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 130504 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 10	2	0.1	2	2
# 13	1	0.0	2	0 0 1
# 14	5	0.0	2	0 1 4
# 15	4	0.0	3	1 0 3
# 16	8	0.0	3	4 0 3 1
# 17	16	0.0	3	3 9 4
# 18	12	0.0	3	3 2 5 1 1
# 19	31	0.0	3	0 4 5 6 16
# 20	139	0.0	4	1 12 75 44 7
# 21	7641	0.0	4	22 5498 1900 206 15
# 22	122356	0.0	4	31181 75569 15110 434 62
# 23	287	0.0	4	3 80 170 29 5
# 41	2	0.0	4	0 2
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505152_101_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505152_101_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       178,248 reads @  13.9 µs/read;   4.31 M reads/minute
# Finished in 2.484 s (13.938 µs/read; 4.30 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 178,248
# Reads with adapters:                   178,019 (99.9%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):       178,019 (99.9%)
#
# Total basepairs processed:    41,204,399 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     37,259,587 bp (90.4%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 178019 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 11	2	0.0	2	2
# 12	2	0.0	2	0 0 2
# 13	1	0.0	2	0 1
# 14	1	0.0	2	1
# 15	7	0.0	3	1 2 3 1
# 16	10	0.0	3	1 6 2 1
# 17	14	0.0	3	9 3 2
# 18	24	0.0	3	6 4 4 9 1
# 19	49	0.0	3	4 5 10 30
# 20	249	0.0	4	5 19 201 20 4
# 21	17189	0.0	4	73 15338 1716 51 11
# 22	160141	0.0	4	153065 6367 594 81 34
# 23	329	0.0	4	56 255 14 3 1
# 35	1	0.0	4	1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505153_102_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505153_102_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        35,089 reads @  15.5 µs/read;   3.86 M reads/minute
# Finished in 0.547 s (15.596 µs/read; 3.85 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  35,089
# Reads with adapters:                    34,991 (99.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        34,991 (99.7%)
#
# Total basepairs processed:     5,550,412 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      4,795,439 bp (86.4%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 34991 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	1	0.0	2	0 1
# 14	5	0.0	2	0 2 2 1
# 15	4	0.0	3	2 2
# 16	10	0.0	3	0 5 3 2
# 17	9	0.0	3	0 4 2 3
# 18	10	0.0	3	0 2 3 4 1
# 19	41	0.0	3	1 4 4 20 12
# 20	500	0.0	4	0 23 296 167 14
# 21	27879	0.0	4	8 19187 8496 169 19
# 22	6522	0.0	4	5578 571 325 38 10
# 23	9	0.0	4	0 7 2
# 60	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505154_103_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505154_103_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        18,785 reads @  16.2 µs/read;   3.70 M reads/minute
# Finished in 0.307 s (16.320 µs/read; 3.68 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  18,785
# Reads with adapters:                    18,687 (99.5%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        18,687 (99.5%)
#
# Total basepairs processed:     3,627,703 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      3,210,719 bp (88.5%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 18687 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 12	1	0.0	2	0 0 1
# 14	4	0.0	2	0 4
# 15	1	0.0	3	0 1
# 16	2	0.0	3	0 1 1
# 17	5	0.0	3	0 1 4
# 18	6	0.0	3	1 2 1 2
# 19	41	0.0	3	0 1 8 30 2
# 20	730	0.0	4	1 26 571 126 6
# 21	8526	0.0	4	28 6864 1502 111 21
# 22	9348	0.0	4	7979 1115 195 37 22
# 23	21	0.0	4	5 12 3 0 1
# 24	2	0.0	4	0 1 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505155_104_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505155_104_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        32,475 reads @  16.1 µs/read;   3.72 M reads/minute
# Finished in 0.526 s (16.202 µs/read; 3.70 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  32,475
# Reads with adapters:                    32,366 (99.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   0 (0.0%)
# Reads written (passing filters):        32,366 (99.7%)
#
# Total basepairs processed:     5,981,020 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,266,313 bp (88.1%)
#
# === Adapter 1 ===
#
# Sequence: CTTGGTCATTTAGAGGAAGTAA; Type: regular 5'; Length: 22; Trimmed: 32366 times
#
# Minimum overlap: 8
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20-22 bp: 4
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	1	0.0	2	0 1
# 15	3	0.0	3	0 2 1
# 16	5	0.0	3	2 2 1
# 17	5	0.0	3	2 0 2 1
# 18	11	0.0	3	0 3 1 6 1
# 19	55	0.0	3	0 2 16 28 9
# 20	1225	0.0	4	2 42 950 214 17
# 21	13997	0.0	4	60 10937 2811 168 21
# 22	17025	0.0	4	14266 2376 300 58 25
# 23	34	0.0	4	5 20 3 1 5
# 24	1	0.0	4	0 0 1
# 25	1	0.0	4	0 0 1
# 26	1	0.0	4	0 0 0 0 1
# 32	1	0.0	4	0 1
# 38	1	0.0	4	0 0 1
# cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505139_88_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505139_88_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505140_89_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505140_89_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505141_90_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505141_90_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505142_91_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505142_91_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505143_92_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505143_92_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505144_93_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505144_93_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505145_94_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505145_94_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505146_95_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505146_95_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505147_96_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505147_96_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505148_97_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505148_97_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505149_98_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505149_98_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505150_99_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505150_99_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505151_100_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505151_100_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505152_101_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505152_101_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505153_102_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505153_102_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505154_103_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505154_103_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 8 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-3yze1esv/SRR10505155_104_L001_R1_001.fastq.gz --front CTTGGTCATTTAGAGGAAGTAA --discard-untrimmed /tmp/qiime2/jovyan/data/f11bd813-cc41-4c3f-be1f-86834fa49ff0/data/SRR10505155_104_L001_R1_001.fastq.gz
#
# Saved SampleData[SequencesWithQuality] to: data/preprocessing/pundemic_forward_reads_trimmed_QCfiltered.qza

# %%
! qiime demux summarize \
    --i-data $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered.qza  \
    --o-visualization $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered.qzv
# Out:
# Saved Visualization to: data/preprocessing/pundemic_forward_reads_trimmed_QCfiltered.qzv

# %%
Visualization.load(f"{data_dir_pre}/pundemic_forward_reads_trimmed_QCfiltered.qzv")
# Out:
# <visualization: Visualization uuid: b72c4dab-097f-4f31-b4f9-1c983df50757>

# %%
# Trim reverse compliment of back primer 3' 
! qiime cutadapt trim-single \
  --i-demultiplexed-sequences $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered.qza \
  --p-adapter GCATCGATGAAGAACGCAGC \
  --p-error-rate 0.2 \
  --p-overlap 16 \
  --verbose \
  --o-trimmed-sequences $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered_2.qza | tee $data_dir_pre/cutadapt_forward_backward_results.txt
# Out:
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505051_0_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505051_0_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        37,290 reads @  15.9 µs/read;   3.77 M reads/minute
# Finished in 0.595 s (15.962 µs/read; 3.76 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  37,290
# Reads with adapters:                    13,296 (35.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                   6 (0.0%)
# Reads written (passing filters):        37,284 (100.0%)
#
# Total basepairs processed:     6,717,839 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      6,492,919 bp (96.7%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 13296 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 0.7%
#   C: 97.5%
#   G: 0.9%
#   T: 0.9%
#   none/other: 0.0%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	11233	0.0	2	0 0 0 11233
# 14	1085	0.0	2	0 0 1034 51
# 15	57	0.0	3	0 46 4 7
# 16	13	0.0	3	9 3 1
# 17	9	0.0	3	4 4 0 1
# 18	9	0.0	3	4 1 1 3
# 19	10	0.0	3	5 1 1 2 1
# 20	7	0.0	4	3 0 1 3
# 21	2	0.0	4	0 0 2
# 22	5	0.0	4	1 2 0 0 2
# 23	2	0.0	4	1 0 1
# 24	1	0.0	4	0 1
# 25	1	0.0	4	0 0 0 1
# 26	2	0.0	4	0 1 0 0 1
# 27	3	0.0	4	0 0 1 1 1
# 29	1	0.0	4	0 0 0 0 1
# 30	1	0.0	4	0 0 1
# 31	2	0.0	4	1 1
# 33	1	0.0	4	0 0 1
# 34	2	0.0	4	1 1
# 35	3	0.0	4	0 1 1 1
# 36	4	0.0	4	1 1 1 0 1
# 37	1	0.0	4	0 0 1
# 38	4	0.0	4	0 1 0 1 2
# 39	3	0.0	4	0 1 2
# 40	6	0.0	4	2 1 0 3
# 41	21	0.0	4	2 3 6 5 5
# 42	10	0.0	4	1 3 4 1 1
# 43	3	0.0	4	1 2
# 44	7	0.0	4	3 0 2 1 1
# 45	2	0.0	4	1 1
# 46	7	0.0	4	1 1 2 2 1
# 47	14	0.0	4	2 4 2 4 2
# 48	31	0.0	4	11 6 8 4 2
# 49	22	0.0	4	4 3 6 6 3
# 50	7	0.0	4	5 1 0 0 1
# 51	3	0.0	4	2 1
# 52	1	0.0	4	0 0 1
# 53	5	0.0	4	2 1 0 0 2
# 54	5	0.0	4	3 1 0 1
# 55	10	0.0	4	1 3 3 1 2
# 56	16	0.0	4	5 3 1 5 2
# 57	16	0.0	4	1 3 7 3 2
# 58	9	0.0	4	2 3 1 3
# 59	8	0.0	4	3 1 2 1 1
# 60	26	0.0	4	4 4 11 5 2
# 61	11	0.0	4	2 5 2 1 1
# 62	188	0.0	4	162 19 4 2 1
# 63	22	0.0	4	14 4 2 2
# 64	6	0.0	4	4 1 1
# 65	6	0.0	4	2 3 0 1
# 66	2	0.0	4	1 0 1
# 67	4	0.0	4	3 1
# 68	2	0.0	4	0 0 2
# 69	7	0.0	4	4 1 2
# 70	6	0.0	4	2 2 1 1
# 71	5	0.0	4	4 1
# 73	5	0.0	4	2 0 3
# 74	3	0.0	4	0 0 1 1 1
# 75	8	0.0	4	2 3 2 0 1
# 76	3	0.0	4	1 1 1
# 77	2	0.0	4	0 0 1 0 1
# 78	2	0.0	4	0 0 1 1
# 79	6	0.0	4	2 3 0 0 1
# 80	1	0.0	4	0 1
# 81	3	0.0	4	3
# 82	3	0.0	4	2 0 1
# 83	53	0.0	4	34 12 2 3 2
# 84	1	0.0	4	1
# 85	120	0.0	4	98 15 5 2
# 86	5	0.0	4	3 1 1
# 88	1	0.0	4	1
# 89	11	0.0	4	10 0 0 1
# 90	4	0.0	4	4
# 91	1	0.0	4	0 0 1
# 92	12	0.0	4	8 1 0 3
# 93	4	0.0	4	1 2 1
# 94	3	0.0	4	1 0 2
# 95	4	0.0	4	4
# 96	7	0.0	4	6 1
# 97	7	0.0	4	7
# 98	4	0.0	4	3 0 1
# 99	7	0.0	4	5 2
# 100	6	0.0	4	3 0 2 1
# 101	4	0.0	4	3 0 1
# 102	3	0.0	4	2 1
# 103	4	0.0	4	2 1 1
# 104	4	0.0	4	1 2 0 1
# 105	2	0.0	4	2
# 106	1	0.0	4	1
# 107	1	0.0	4	0 1
# 109	1	0.0	4	1
# 111	1	0.0	4	1
# 112	2	0.0	4	1 0 1
# 113	2	0.0	4	0 0 1 0 1
# 115	1	0.0	4	1
# 118	1	0.0	4	1
# 120	1	0.0	4	1
# 121	1	0.0	4	1
# 123	2	0.0	4	2
# 124	1	0.0	4	1
# 125	1	0.0	4	0 0 0 1
# 126	1	0.0	4	0 1
# 128	1	0.0	4	0 0 1
# 131	1	0.0	4	1
# 132	1	0.0	4	1
# 133	1	0.0	4	1
# 135	1	0.0	4	0 0 0 1
# 146	1	0.0	4	1
# 158	1	0.0	4	1
# 160	1	0.0	4	0 1
# 165	1	0.0	4	1
# 167	1	0.0	4	1
# 168	1	0.0	4	0 1
# 170	2	0.0	4	2
# 172	1	0.0	4	1
# 175	1	0.0	4	1
# 176	1	0.0	4	0 0 1
# 178	1	0.0	4	0 0 0 0 1
# 183	1	0.0	4	1
# 184	1	0.0	4	1
# 190	2	0.0	4	1 0 0 0 1
# 193	1	0.0	4	1
# 198	1	0.0	4	1
# 205	1	0.0	4	1
# 209	1	0.0	4	0 0 0 0 1
# 216	1	0.0	4	1
# 228	1	0.0	4	1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505052_1_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505052_1_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        16,611 reads @  18.5 µs/read;   3.25 M reads/minute
# Finished in 0.309 s (18.616 µs/read; 3.22 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  16,611
# Reads with adapters:                     1,694 (10.2%)
#
# == Read fate breakdown ==
# Reads that were too short:                  30 (0.2%)
# Reads written (passing filters):        16,581 (99.8%)
#
# Total basepairs processed:     2,808,778 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,714,794 bp (96.7%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 1694 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 8.6%
#   C: 53.1%
#   G: 19.8%
#   T: 16.7%
#   none/other: 1.8%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	253	0.0	2	0 0 0 253
# 14	197	0.0	2	0 0 187 10
# 15	136	0.0	3	0 129 6 1
# 16	19	0.0	3	7 4 4 4
# 17	5	0.0	3	0 3 2
# 18	5	0.0	3	2 0 2 1
# 19	16	0.0	3	15 1
# 20	7	0.0	4	0 3 3 0 1
# 21	5	0.0	4	2 1 1 1
# 22	1	0.0	4	0 0 1
# 23	1	0.0	4	0 0 0 1
# 27	1	0.0	4	0 0 0 1
# 28	11	0.0	4	7 2 1 0 1
# 29	8	0.0	4	6 0 2
# 30	10	0.0	4	7 3
# 31	1	0.0	4	1
# 34	2	0.0	4	0 0 0 0 2
# 35	1	0.0	4	0 0 0 1
# 36	1	0.0	4	1
# 37	1	0.0	4	0 0 0 0 1
# 38	4	0.0	4	0 0 1 0 3
# 39	3	0.0	4	0 0 1 1 1
# 40	41	0.0	4	29 8 2 2
# 41	8	0.0	4	4 2 1 1
# 42	2	0.0	4	0 0 2
# 43	3	0.0	4	1 2
# 44	4	0.0	4	1 1 0 1 1
# 45	2	0.0	4	0 1 1
# 46	3	0.0	4	1 0 1 0 1
# 47	3	0.0	4	0 2 0 1
# 48	9	0.0	4	2 1 1 3 2
# 49	10	0.0	4	2 3 2 1 2
# 50	7	0.0	4	2 3 1 0 1
# 51	7	0.0	4	7
# 52	7	0.0	4	4 1 1 0 1
# 53	52	0.0	4	46 4 1 0 1
# 54	6	0.0	4	1 3 0 1 1
# 55	7	0.0	4	4 1 0 0 2
# 56	6	0.0	4	1 1 0 2 2
# 57	1	0.0	4	0 1
# 59	1	0.0	4	0 0 1
# 60	9	0.0	4	4 0 2 3
# 61	4	0.0	4	2 1 1
# 62	6	0.0	4	1 0 2 2 1
# 63	3	0.0	4	2 0 0 1
# 64	59	0.0	4	55 2 1 1
# 65	99	0.0	4	89 8 1 0 1
# 66	2	0.0	4	1 0 0 1
# 67	13	0.0	4	1 0 12
# 68	4	0.0	4	0 0 2 1 1
# 69	15	0.0	4	5 0 9 1
# 70	1	0.0	4	0 0 0 0 1
# 71	7	0.0	4	7
# 72	9	0.0	4	7 0 2
# 73	1	0.0	4	0 1
# 74	4	0.0	4	1 3
# 75	2	0.0	4	1 0 0 1
# 78	4	0.0	4	2 2
# 79	2	0.0	4	1 1
# 80	1	0.0	4	1
# 81	4	0.0	4	2 0 0 2
# 82	1	0.0	4	1
# 83	3	0.0	4	1 0 1 1
# 84	4	0.0	4	4
# 85	9	0.0	4	7 0 2
# 86	53	0.0	4	4 0 42 7
# 87	134	0.0	4	124 6 3 1
# 88	6	0.0	4	5 0 0 0 1
# 89	9	0.0	4	4 0 4 1
# 90	34	0.0	4	23 1 9 1
# 91	4	0.0	4	1 0 2 0 1
# 92	6	0.0	4	4 1 1
# 93	12	0.0	4	7 1 2 0 2
# 94	11	0.0	4	7 0 1 2 1
# 95	25	0.0	4	15 4 1 3 2
# 96	30	0.0	4	19 2 3 6
# 97	17	0.0	4	10 1 2 3 1
# 98	20	0.0	4	11 3 1 1 4
# 99	11	0.0	4	2 3 1 4 1
# 100	18	0.0	4	9 1 1 6 1
# 101	10	0.0	4	5 3 0 1 1
# 102	7	0.0	4	4 1 1 1
# 103	9	0.0	4	2 2 4 0 1
# 104	6	0.0	4	5 1
# 105	15	0.0	4	10 0 0 3 2
# 106	5	0.0	4	4 0 0 1
# 107	7	0.0	4	4 1 0 1 1
# 108	5	0.0	4	3 1 0 0 1
# 109	2	0.0	4	0 0 1 1
# 110	1	0.0	4	1
# 111	5	0.0	4	3 1 0 1
# 112	1	0.0	4	1
# 113	1	0.0	4	1
# 114	5	0.0	4	4 1
# 115	5	0.0	4	4 0 1
# 116	4	0.0	4	4
# 117	4	0.0	4	3 0 0 0 1
# 118	2	0.0	4	2
# 119	2	0.0	4	1 0 0 0 1
# 120	1	0.0	4	0 1
# 121	3	0.0	4	2 0 0 1
# 122	4	0.0	4	3 0 1
# 123	4	0.0	4	3 1
# 124	2	0.0	4	1 0 0 1
# 125	1	0.0	4	0 0 0 0 1
# 126	2	0.0	4	1 1
# 127	1	0.0	4	0 0 0 0 1
# 129	2	0.0	4	0 1 0 1
# 131	3	0.0	4	3
# 132	3	0.0	4	1 0 1 1
# 133	2	0.0	4	1 1
# 134	1	0.0	4	0 0 0 0 1
# 135	5	0.0	4	4 0 0 1
# 137	1	0.0	4	0 0 0 0 1
# 138	1	0.0	4	0 0 1
# 139	1	0.0	4	0 0 0 1
# 141	1	0.0	4	1
# 142	1	0.0	4	1
# 143	2	0.0	4	2
# 145	1	0.0	4	1
# 147	2	0.0	4	0 1 0 1
# 148	1	0.0	4	1
# 149	3	0.0	4	1 1 0 0 1
# 151	1	0.0	4	0 1
# 152	1	0.0	4	1
# 153	2	0.0	4	0 1 1
# 155	1	0.0	4	0 1
# 157	1	0.0	4	0 0 0 0 1
# 158	1	0.0	4	1
# 159	1	0.0	4	1
# 160	1	0.0	4	0 1
# 161	1	0.0	4	1
# 163	1	0.0	4	1
# 174	1	0.0	4	0 1
# 175	1	0.0	4	1
# 177	2	0.0	4	2
# 182	2	0.0	4	0 0 1 1
# 186	1	0.0	4	1
# 187	1	0.0	4	1
# 189	1	0.0	4	0 0 1
# 195	1	0.0	4	1
# 205	1	0.0	4	1
# 208	1	0.0	4	0 0 0 1
# 212	1	0.0	4	0 1
# 217	1	0.0	4	0 0 0 0 1
# 221	1	0.0	4	0 0 0 1
# 224	1	0.0	4	0 0 0 0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505053_2_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505053_2_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        91,086 reads @  15.6 µs/read;   3.85 M reads/minute
# Finished in 1.421 s (15.601 µs/read; 3.85 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  91,086
# Reads with adapters:                     3,634 (4.0%)
#
# == Read fate breakdown ==
# Reads that were too short:                  45 (0.0%)
# Reads written (passing filters):        91,041 (100.0%)
#
# Total basepairs processed:    18,483,550 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     18,216,196 bp (98.6%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 3634 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 24.1%
#   C: 38.5%
#   G: 18.1%
#   T: 18.1%
#   none/other: 1.2%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	142	0.0	2	0 0 0 142
# 14	136	0.0	2	0 0 119 17
# 15	134	0.0	3	0 110 9 15
# 16	12	0.0	3	5 3 3 1
# 17	16	0.0	3	6 2 2 6
# 18	11	0.0	3	0 2 5 4
# 19	5	0.0	3	2 1 2
# 20	18	0.0	4	2 3 9 1 3
# 21	4	0.0	4	1 1 1 1
# 22	2	0.0	4	0 0 0 0 2
# 23	1	0.0	4	0 0 0 0 1
# 25	1	0.0	4	0 1
# 26	2	0.0	4	0 0 1 0 1
# 27	124	0.0	4	110 8 4 0 2
# 28	6	0.0	4	3 3
# 29	4	0.0	4	0 2 2
# 30	2	0.0	4	1 0 1
# 31	5	0.0	4	1 0 2 1 1
# 32	15	0.0	4	12 1 1 1
# 33	3	0.0	4	0 1 1 0 1
# 34	5	0.0	4	0 0 2 2 1
# 35	2	0.0	4	1 0 0 1
# 36	3	0.0	4	0 1 2
# 37	5	0.0	4	0 2 2 1
# 39	6	0.0	4	2 2 0 2
# 40	12	0.0	4	3 5 1 1 2
# 41	19	0.0	4	7 5 4 1 2
# 42	46	0.0	4	32 2 9 0 3
# 43	15	0.0	4	5 4 1 3 2
# 44	10	0.0	4	3 1 3 3
# 45	10	0.0	4	2 3 4 0 1
# 46	6	0.0	4	2 2 0 1 1
# 47	15	0.0	4	2 4 5 3 1
# 48	74	0.0	4	61 7 3 2 1
# 49	31	0.0	4	17 2 4 3 5
# 50	15	0.0	4	5 5 2 2 1
# 51	14	0.0	4	5 3 4 2
# 52	7	0.0	4	2 2 1 2
# 53	37	0.0	4	32 1 1 0 3
# 54	12	0.0	4	8 2 2
# 55	16	0.0	4	5 4 3 4
# 56	19	0.0	4	10 1 5 2 1
# 57	13	0.0	4	3 4 4 1 1
# 58	10	0.0	4	7 0 1 1 1
# 59	5	0.0	4	1 0 3 0 1
# 60	14	0.0	4	2 0 3 8 1
# 61	26	0.0	4	19 6 1
# 62	25	0.0	4	17 4 1 1 2
# 63	15	0.0	4	10 3 0 2
# 64	553	0.0	4	496 51 4 2
# 65	64	0.0	4	54 8 2
# 66	7	0.0	4	3 3 1
# 67	26	0.0	4	12 1 12 0 1
# 68	6	0.0	4	5 1
# 69	28	0.0	4	7 7 10 4
# 70	9	0.0	4	4 2 0 2 1
# 71	6	0.0	4	2 0 2 2
# 72	31	0.0	4	26 3 1 0 1
# 73	10	0.0	4	9 0 0 1
# 74	11	0.0	4	3 4 1 1 2
# 75	10	0.0	4	4 5 1
# 76	1	0.0	4	1
# 77	2	0.0	4	1 1
# 78	74	0.0	4	66 4 1 3
# 79	11	0.0	4	9 1 1
# 80	4	0.0	4	3 0 0 0 1
# 81	8	0.0	4	2 2 2 1 1
# 82	5	0.0	4	2 0 0 1 2
# 83	38	0.0	4	30 6 1 0 1
# 84	4	0.0	4	3 1
# 85	22	0.0	4	10 5 4 2 1
# 86	34	0.0	4	28 4 2
# 87	9	0.0	4	7 1 1
# 88	3	0.0	4	2 0 1
# 89	10	0.0	4	5 2 2 0 1
# 90	65	0.0	4	56 5 2 2
# 91	16	0.0	4	11 2 2 1
# 92	228	0.0	4	191 28 9
# 93	19	0.0	4	10 5 1 3
# 94	45	0.0	4	23 8 3 10 1
# 95	68	0.0	4	44 10 6 7 1
# 96	164	0.0	4	138 15 5 5 1
# 97	113	0.0	4	96 9 5 1 2
# 98	88	0.0	4	72 11 3 2
# 99	63	0.0	4	47 10 3 1 2
# 100	45	0.0	4	33 7 2 2 1
# 101	40	0.0	4	34 4 2
# 102	36	0.0	4	27 2 1 4 2
# 103	36	0.0	4	27 5 3 1
# 104	27	0.0	4	20 1 4 2
# 105	24	0.0	4	14 8 1 1
# 106	28	0.0	4	23 2 1 2
# 107	20	0.0	4	14 2 4
# 108	13	0.0	4	11 2
# 109	15	0.0	4	11 4
# 110	16	0.0	4	12 1 2 1
# 111	11	0.0	4	6 4 1
# 112	16	0.0	4	11 4 0 1
# 113	6	0.0	4	5 1
# 114	13	0.0	4	6 5 2
# 115	12	0.0	4	9 1 1 1
# 116	8	0.0	4	6 0 1 0 1
# 117	10	0.0	4	8 2
# 118	8	0.0	4	6 1 0 1
# 119	8	0.0	4	4 2 2
# 120	11	0.0	4	9 1 0 0 1
# 121	9	0.0	4	6 3
# 122	6	0.0	4	4 2
# 123	6	0.0	4	5 0 1
# 124	8	0.0	4	7 1
# 125	7	0.0	4	7
# 126	6	0.0	4	4 0 0 1 1
# 127	8	0.0	4	5 1 1 0 1
# 128	4	0.0	4	3 1
# 129	5	0.0	4	4 1
# 130	7	0.0	4	5 1 1
# 131	7	0.0	4	7
# 132	5	0.0	4	4 1
# 133	6	0.0	4	5 1
# 134	5	0.0	4	3 1 0 1
# 135	2	0.0	4	2
# 136	2	0.0	4	2
# 137	3	0.0	4	2 1
# 138	2	0.0	4	0 1 0 1
# 139	2	0.0	4	2
# 140	3	0.0	4	2 0 0 1
# 141	4	0.0	4	2 2
# 142	7	0.0	4	4 1 1 1
# 143	4	0.0	4	3 0 1
# 144	2	0.0	4	1 1
# 145	1	0.0	4	1
# 146	4	0.0	4	1 2 1
# 147	11	0.0	4	8 1 0 1 1
# 148	2	0.0	4	1 1
# 149	2	0.0	4	1 1
# 150	3	0.0	4	2 1
# 151	1	0.0	4	1
# 152	4	0.0	4	3 1
# 154	1	0.0	4	0 0 0 1
# 155	1	0.0	4	1
# 156	3	0.0	4	2 1
# 157	1	0.0	4	1
# 158	1	0.0	4	1
# 160	2	0.0	4	1 0 0 1
# 161	2	0.0	4	0 1 1
# 162	4	0.0	4	3 1
# 163	4	0.0	4	2 1 0 0 1
# 164	2	0.0	4	1 1
# 166	1	0.0	4	1
# 167	3	0.0	4	3
# 168	4	0.0	4	3 1
# 169	2	0.0	4	2
# 171	1	0.0	4	0 1
# 172	1	0.0	4	1
# 173	1	0.0	4	0 1
# 174	3	0.0	4	0 3
# 175	1	0.0	4	0 1
# 176	3	0.0	4	2 1
# 177	2	0.0	4	2
# 178	1	0.0	4	0 1
# 179	2	0.0	4	2
# 180	1	0.0	4	1
# 181	1	0.0	4	1
# 182	1	0.0	4	1
# 183	6	0.0	4	5 1
# 184	1	0.0	4	1
# 185	3	0.0	4	2 1
# 188	2	0.0	4	2
# 189	2	0.0	4	1 0 0 1
# 190	1	0.0	4	1
# 191	1	0.0	4	1
# 192	2	0.0	4	1 1
# 193	2	0.0	4	2
# 194	1	0.0	4	0 0 0 1
# 196	1	0.0	4	0 1
# 197	1	0.0	4	0 1
# 198	1	0.0	4	0 0 1
# 200	1	0.0	4	1
# 203	1	0.0	4	1
# 204	3	0.0	4	3
# 205	1	0.0	4	0 1
# 207	1	0.0	4	1
# 210	1	0.0	4	0 1
# 212	1	0.0	4	0 1
# 213	4	0.0	4	3 1
# 216	5	0.0	4	4 1
# 218	1	0.0	4	1
# 219	1	0.0	4	0 1
# 221	1	0.0	4	0 1
# 223	1	0.0	4	0 1
# 225	1	0.0	4	0 1
# 226	1	0.0	4	0 0 0 0 1
# 228	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505054_3_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505054_3_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        11,311 reads @  13.0 µs/read;   4.62 M reads/minute
# Finished in 0.149 s (13.191 µs/read; 4.55 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  11,311
# Reads with adapters:                     1,029 (9.1%)
#
# == Read fate breakdown ==
# Reads that were too short:                   2 (0.0%)
# Reads written (passing filters):        11,309 (100.0%)
#
# Total basepairs processed:     1,438,818 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      1,397,046 bp (97.1%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 1029 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 8.4%
#   C: 78.0%
#   G: 6.4%
#   T: 7.0%
#   none/other: 0.2%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	464	0.0	2	0 0 0 464
# 14	39	0.0	2	0 0 34 5
# 15	14	0.0	3	0 6 2 6
# 16	13	0.0	3	8 3 2
# 17	7	0.0	3	1 3 0 3
# 18	8	0.0	3	1 0 4 3
# 19	6	0.0	3	2 3 1
# 20	2	0.0	4	0 1 0 1
# 21	1	0.0	4	0 0 1
# 22	5	0.0	4	1 1 1 2
# 25	3	0.0	4	0 2 1
# 27	1	0.0	4	0 0 0 1
# 29	1	0.0	4	1
# 30	1	0.0	4	1
# 32	1	0.0	4	0 0 1
# 33	2	0.0	4	0 0 0 1 1
# 34	1	0.0	4	0 0 0 0 1
# 35	2	0.0	4	1 0 0 0 1
# 37	3	0.0	4	1 1 0 0 1
# 38	2	0.0	4	0 1 0 1
# 39	5	0.0	4	1 0 2 2
# 40	7	0.0	4	1 4 0 1 1
# 41	20	0.0	4	4 3 7 4 2
# 42	6	0.0	4	0 1 4 1
# 43	5	0.0	4	2 0 0 0 3
# 44	3	0.0	4	2 0 0 0 1
# 45	6	0.0	4	3 1 2
# 46	6	0.0	4	1 1 1 2 1
# 47	5	0.0	4	2 0 2 1
# 48	14	0.0	4	3 3 3 2 3
# 49	12	0.0	4	2 5 0 4 1
# 50	7	0.0	4	2 1 3 0 1
# 51	2	0.0	4	0 0 2
# 52	5	0.0	4	3 1 0 0 1
# 53	2	0.0	4	0 1 0 0 1
# 54	3	0.0	4	1 0 2
# 55	5	0.0	4	1 1 2 0 1
# 56	6	0.0	4	0 0 4 1 1
# 57	10	0.0	4	0 4 4 2
# 58	2	0.0	4	0 1 1
# 59	4	0.0	4	1 2 1
# 60	15	0.0	4	1 4 9 1
# 61	9	0.0	4	3 5 0 0 1
# 62	27	0.0	4	10 8 7 2
# 63	11	0.0	4	5 2 1 2 1
# 64	3	0.0	4	1 0 1 0 1
# 65	4	0.0	4	3 1
# 66	4	0.0	4	1 0 1 2
# 67	7	0.0	4	4 2 0 0 1
# 68	1	0.0	4	1
# 69	3	0.0	4	1 1 1
# 70	2	0.0	4	0 0 1 1
# 71	1	0.0	4	0 0 1
# 72	4	0.0	4	3 1
# 73	2	0.0	4	2
# 74	4	0.0	4	4
# 75	3	0.0	4	3
# 76	1	0.0	4	1
# 77	4	0.0	4	2 2
# 78	2	0.0	4	2
# 79	3	0.0	4	1 1 1
# 80	1	0.0	4	0 1
# 81	2	0.0	4	1 0 1
# 83	34	0.0	4	23 9 1 1
# 84	1	0.0	4	1
# 85	36	0.0	4	27 4 2 3
# 86	9	0.0	4	6 2 0 0 1
# 87	1	0.0	4	0 1
# 89	9	0.0	4	6 2 0 1
# 91	3	0.0	4	2 0 0 1
# 92	7	0.0	4	5 2
# 93	1	0.0	4	1
# 95	8	0.0	4	6 2
# 96	16	0.0	4	12 3 1
# 97	8	0.0	4	6 2
# 98	8	0.0	4	6 2
# 99	7	0.0	4	6 1
# 100	10	0.0	4	8 0 0 0 2
# 101	4	0.0	4	3 0 0 0 1
# 102	10	0.0	4	6 2 1 0 1
# 103	5	0.0	4	3 1 1
# 104	1	0.0	4	1
# 105	2	0.0	4	2
# 106	3	0.0	4	2 1
# 107	2	0.0	4	1 0 1
# 109	1	0.0	4	1
# 111	1	0.0	4	0 1
# 112	1	0.0	4	1
# 114	1	0.0	4	1
# 115	2	0.0	4	2
# 117	1	0.0	4	1
# 120	1	0.0	4	0 1
# 122	1	0.0	4	0 1
# 123	2	0.0	4	1 0 0 0 1
# 142	1	0.0	4	1
# 148	1	0.0	4	0 1
# 151	1	0.0	4	1
# 154	1	0.0	4	1
# 171	1	0.0	4	0 1
# 174	1	0.0	4	1
# 177	1	0.0	4	1
# 198	1	0.0	4	0 0 1
# 201	1	0.0	4	1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505055_4_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505055_4_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        22,794 reads @  13.6 µs/read;   4.43 M reads/minute
# Finished in 0.311 s (13.654 µs/read; 4.39 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  22,794
# Reads with adapters:                     2,114 (9.3%)
#
# == Read fate breakdown ==
# Reads that were too short:                   6 (0.0%)
# Reads written (passing filters):        22,788 (100.0%)
#
# Total basepairs processed:     2,909,737 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,818,573 bp (96.9%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 2114 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 10.9%
#   C: 70.3%
#   G: 12.2%
#   T: 6.3%
#   none/other: 0.3%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	142	0.0	2	0 0 0 142
# 14	860	0.0	2	0 0 822 38
# 15	56	0.0	3	0 36 14 6
# 16	19	0.0	3	7 5 2 5
# 17	17	0.0	3	3 3 4 7
# 18	16	0.0	3	5 3 7 1
# 19	8	0.0	3	4 2 1 1
# 20	7	0.0	4	1 2 1 1 2
# 21	14	0.0	4	2 4 1 3 4
# 22	3	0.0	4	2 0 1
# 23	3	0.0	4	0 1 0 1 1
# 24	2	0.0	4	0 1 0 1
# 25	5	0.0	4	3 1 1
# 26	2	0.0	4	0 1 0 1
# 27	3	0.0	4	0 1 1 0 1
# 28	3	0.0	4	0 0 3
# 29	1	0.0	4	0 1
# 30	3	0.0	4	0 0 1 2
# 31	2	0.0	4	1 0 0 0 1
# 32	2	0.0	4	1 0 1
# 33	5	0.0	4	1 0 2 1 1
# 34	14	0.0	4	0 0 1 10 3
# 35	3	0.0	4	2 0 0 0 1
# 36	5	0.0	4	2 0 1 1 1
# 37	3	0.0	4	0 0 0 1 2
# 38	2	0.0	4	0 1 0 0 1
# 39	5	0.0	4	1 0 3 1
# 40	17	0.0	4	6 7 3 1
# 41	28	0.0	4	7 8 4 3 6
# 42	22	0.0	4	16 3 1 1 1
# 43	9	0.0	4	3 1 1 3 1
# 44	7	0.0	4	2 0 0 3 2
# 45	4	0.0	4	1 0 0 2 1
# 46	6	0.0	4	4 0 1 1
# 47	21	0.0	4	4 6 4 3 4
# 48	23	0.0	4	9 3 2 6 3
# 49	24	0.0	4	5 10 5 2 2
# 50	12	0.0	4	3 3 4 1 1
# 51	5	0.0	4	2 2 1
# 52	5	0.0	4	1 2 1 1
# 53	21	0.0	4	13 5 3
# 54	2	0.0	4	2
# 55	6	0.0	4	3 1 1 0 1
# 56	8	0.0	4	1 0 2 3 2
# 57	21	0.0	4	6 3 7 3 2
# 58	7	0.0	4	3 4
# 59	10	0.0	4	4 0 1 5
# 60	20	0.0	4	6 4 7 2 1
# 61	11	0.0	4	5 3 3
# 62	35	0.0	4	21 7 5 2
# 63	9	0.0	4	5 2 0 2
# 64	9	0.0	4	4 4 1
# 65	5	0.0	4	1 1 1 2
# 66	2	0.0	4	0 0 2
# 67	6	0.0	4	1 3 2
# 68	5	0.0	4	2 0 3
# 69	6	0.0	4	2 2 1 0 1
# 70	5	0.0	4	2 0 0 2 1
# 71	5	0.0	4	2 2 0 1
# 72	16	0.0	4	15 0 1
# 73	4	0.0	4	2 1 0 1
# 74	12	0.0	4	6 3 1 2
# 75	6	0.0	4	5 1
# 76	5	0.0	4	3 1 1
# 77	3	0.0	4	3
# 78	5	0.0	4	5
# 79	2	0.0	4	1 1
# 80	5	0.0	4	2 2 0 1
# 81	4	0.0	4	3 0 1
# 82	4	0.0	4	1 1 0 1 1
# 83	40	0.0	4	28 6 5 1
# 84	9	0.0	4	8 1
# 85	44	0.0	4	25 15 3 0 1
# 86	11	0.0	4	5 0 6
# 87	3	0.0	4	1 0 0 2
# 88	2	0.0	4	1 1
# 89	10	0.0	4	7 1 1 0 1
# 90	9	0.0	4	8 0 0 1
# 91	3	0.0	4	2 0 1
# 92	15	0.0	4	13 0 0 0 2
# 93	4	0.0	4	2 1 0 1
# 94	7	0.0	4	4 1 1 1
# 95	18	0.0	4	12 5 0 0 1
# 96	43	0.0	4	38 2 1 1 1
# 97	28	0.0	4	17 4 4 2 1
# 98	16	0.0	4	11 4 1
# 99	30	0.0	4	23 5 1 1
# 100	22	0.0	4	17 3 1 1
# 101	9	0.0	4	8 1
# 102	12	0.0	4	9 2 0 0 1
# 103	6	0.0	4	5 0 0 0 1
# 104	6	0.0	4	5 0 1
# 105	13	0.0	4	8 1 1 2 1
# 106	5	0.0	4	3 1 0 1
# 107	3	0.0	4	2 0 0 1
# 108	5	0.0	4	5
# 109	6	0.0	4	5 0 0 0 1
# 110	5	0.0	4	4 0 0 1
# 111	8	0.0	4	7 1
# 112	6	0.0	4	6
# 113	2	0.0	4	2
# 114	3	0.0	4	3
# 115	6	0.0	4	6
# 116	3	0.0	4	3
# 117	1	0.0	4	0 0 1
# 118	2	0.0	4	2
# 119	1	0.0	4	1
# 120	1	0.0	4	1
# 121	2	0.0	4	1 0 1
# 122	2	0.0	4	1 1
# 123	1	0.0	4	0 1
# 125	1	0.0	4	1
# 126	1	0.0	4	1
# 129	1	0.0	4	1
# 130	3	0.0	4	3
# 131	1	0.0	4	1
# 133	1	0.0	4	0 0 0 1
# 134	2	0.0	4	2
# 136	1	0.0	4	1
# 137	1	0.0	4	0 1
# 143	1	0.0	4	1
# 144	1	0.0	4	1
# 145	1	0.0	4	1
# 147	1	0.0	4	1
# 148	1	0.0	4	0 0 0 0 1
# 149	1	0.0	4	1
# 151	1	0.0	4	1
# 152	1	0.0	4	1
# 154	1	0.0	4	1
# 156	1	0.0	4	1
# 157	1	0.0	4	1
# 161	1	0.0	4	0 1
# 163	2	0.0	4	2
# 167	1	0.0	4	1
# 172	1	0.0	4	0 0 1
# 173	1	0.0	4	1
# 177	1	0.0	4	0 1
# 178	1	0.0	4	1
# 180	1	0.0	4	1
# 182	1	0.0	4	0 1
# 187	2	0.0	4	1 1
# 188	1	0.0	4	1
# 191	2	0.0	4	1 1
# 192	1	0.0	4	0 0 0 0 1
# 194	1	0.0	4	1
# 198	1	0.0	4	0 0 1
# 210	1	0.0	4	1
# 220	1	0.0	4	0 1
# 223	1	0.0	4	0 0 0 0 1
# 227	1	0.0	4	0 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505056_5_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505056_5_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:02       159,577 reads @  18.6 µs/read;   3.22 M reads/minute
# Finished in 2.974 s (18.639 µs/read; 3.22 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                 159,577
# Reads with adapters:                    37,665 (23.6%)
#
# == Read fate breakdown ==
# Reads that were too short:               2,060 (1.3%)
# Reads written (passing filters):       157,517 (98.7%)
#
# Total basepairs processed:    34,033,931 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     30,718,156 bp (90.3%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 37665 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 9.5%
#   C: 67.7%
#   G: 10.9%
#   T: 6.5%
#   none/other: 5.5%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	40	0.0	2	0 0 0 40
# 14	713	0.0	2	0 0 687 26
# 15	306	0.0	3	0 241 46 19
# 16	61	0.0	3	43 13 5
# 17	44	0.0	3	26 7 4 7
# 18	17	0.0	3	6 4 2 5
# 19	11	0.0	3	4 3 0 4
# 20	53	0.0	4	9 34 6 2 2
# 21	26	0.0	4	7 7 8 4
# 22	5	0.0	4	2 1 1 0 1
# 23	14	0.0	4	1 0 11 1 1
# 24	3	0.0	4	1 0 0 2
# 25	3	0.0	4	0 0 2 1
# 29	1	0.0	4	0 0 0 1
# 30	27	0.0	4	27
# 32	9	0.0	4	9
# 33	2	0.0	4	1 0 1
# 34	8	0.0	4	2 1 3 2
# 35	2	0.0	4	1 0 0 0 1
# 36	63	0.0	4	58 2 2 1
# 37	6	0.0	4	3 2 1
# 38	15	0.0	4	7 4 2 2
# 39	8	0.0	4	3 1 0 3 1
# 40	31	0.0	4	7 8 9 4 3
# 41	173	0.0	4	93 38 20 12 10
# 42	51	0.0	4	28 7 7 3 6
# 43	42	0.0	4	18 15 5 3 1
# 44	37	0.0	4	12 14 4 4 3
# 45	32	0.0	4	14 11 4 2 1
# 46	108	0.0	4	55 27 15 8 3
# 47	78	0.0	4	39 15 13 9 2
# 48	592	0.0	4	516 44 18 7 7
# 49	185	0.0	4	92 52 14 19 8
# 50	62	0.0	4	37 11 9 4 1
# 51	19	0.0	4	8 5 5 1
# 52	12	0.0	4	7 2 1 1 1
# 53	13	0.0	4	8 2 1 1 1
# 54	118	0.0	4	102 10 3 2 1
# 55	20	0.0	4	7 6 4 2 1
# 56	86	0.0	4	51 15 11 7 2
# 57	124	0.0	4	88 23 6 5 2
# 58	141	0.0	4	91 29 13 5 3
# 59	41	0.0	4	23 14 3 1
# 60	35	0.0	4	9 2 13 7 4
# 61	14	0.0	4	8 2 3 1
# 62	22	0.0	4	13 4 3 2
# 63	51	0.0	4	40 5 0 6
# 64	51	0.0	4	44 5 1 1
# 65	21	0.0	4	13 4 1 2 1
# 66	29	0.0	4	17 8 3 1
# 67	168	0.0	4	91 18 45 10 4
# 68	59	0.0	4	37 13 7 2
# 69	71	0.0	4	33 13 20 1 4
# 70	16	0.0	4	7 5 3 1
# 71	17	0.0	4	7 7 0 2 1
# 72	336	0.0	4	296 34 4 2
# 73	86	0.0	4	62 11 7 3 3
# 74	104	0.0	4	68 22 7 5 2
# 75	49	0.0	4	33 10 1 5
# 76	21	0.0	4	14 4 0 2 1
# 77	34	0.0	4	30 3 1
# 78	98	0.0	4	90 6 0 2
# 79	70	0.0	4	51 10 4 5
# 80	63	0.0	4	48 11 2 2
# 81	44	0.0	4	34 6 3 0 1
# 82	346	0.0	4	314 26 5 1
# 83	37	0.0	4	29 6 1 1
# 84	44	0.0	4	37 6 1
# 85	20718	0.0	4	19206 1283 170 41 18
# 86	1524	0.0	4	1406 106 12
# 87	397	0.0	4	373 17 3 3 1
# 88	25	0.0	4	22 1 2
# 89	22	0.0	4	15 2 2 0 3
# 90	46	0.0	4	31 5 4 3 3
# 91	68	0.0	4	40 14 4 4 6
# 92	1067	0.0	4	972 67 15 3 10
# 93	94	0.0	4	56 18 7 6 7
# 94	152	0.0	4	91 16 28 11 6
# 95	324	0.0	4	222 51 28 15 8
# 96	824	0.0	4	704 71 25 16 8
# 97	733	0.0	4	644 48 17 16 8
# 98	489	0.0	4	406 44 26 9 4
# 99	463	0.0	4	407 25 17 9 5
# 100	306	0.0	4	254 26 15 8 3
# 101	267	0.0	4	244 13 4 5 1
# 102	251	0.0	4	199 27 16 7 2
# 103	222	0.0	4	183 18 11 1 9
# 104	203	0.0	4	165 20 7 8 3
# 105	158	0.0	4	132 15 4 5 2
# 106	156	0.0	4	131 8 10 5 2
# 107	134	0.0	4	117 11 5 1
# 108	131	0.0	4	117 8 5 1
# 109	104	0.0	4	81 4 6 7 6
# 110	94	0.0	4	74 14 3 3
# 111	84	0.0	4	71 5 4 3 1
# 112	94	0.0	4	77 7 3 4 3
# 113	91	0.0	4	69 10 8 0 4
# 114	87	0.0	4	70 9 4 3 1
# 115	123	0.0	4	106 11 1 4 1
# 116	49	0.0	4	39 6 1 2 1
# 117	71	0.0	4	51 9 7 3 1
# 118	74	0.0	4	60 6 3 3 2
# 119	58	0.0	4	48 5 3 1 1
# 120	46	0.0	4	41 3 0 2
# 121	68	0.0	4	59 4 1 2 2
# 122	74	0.0	4	66 4 2 2
# 123	50	0.0	4	42 4 0 3 1
# 124	106	0.0	4	89 11 3 0 3
# 125	54	0.0	4	42 4 3 3 2
# 126	55	0.0	4	39 4 4 6 2
# 127	43	0.0	4	34 5 3 1
# 128	103	0.0	4	84 9 7 2 1
# 129	36	0.0	4	23 5 1 2 5
# 130	49	0.0	4	28 10 10 1
# 131	30	0.0	4	24 2 2 0 2
# 132	42	0.0	4	32 6 0 1 3
# 133	48	0.0	4	36 7 3 1 1
# 134	52	0.0	4	46 1 3 1 1
# 135	38	0.0	4	27 6 2 2 1
# 136	38	0.0	4	31 4 1 1 1
# 137	40	0.0	4	30 4 3 0 3
# 138	37	0.0	4	31 1 2 1 2
# 139	38	0.0	4	29 6 3
# 140	37	0.0	4	24 5 7 0 1
# 141	45	0.0	4	31 6 4 0 4
# 142	22	0.0	4	14 5 1 2
# 143	29	0.0	4	20 2 3 2 2
# 144	33	0.0	4	27 1 3 1 1
# 145	49	0.0	4	38 6 5
# 146	38	0.0	4	27 4 2 3 2
# 147	33	0.0	4	23 6 3 0 1
# 148	52	0.0	4	46 4 0 0 2
# 149	27	0.0	4	24 2 1
# 150	34	0.0	4	23 4 4 2 1
# 151	26	0.0	4	17 6 1 1 1
# 152	16	0.0	4	11 1 2 2
# 153	23	0.0	4	17 2 2 2
# 154	21	0.0	4	13 3 4 1
# 155	18	0.0	4	17 0 0 1
# 156	21	0.0	4	12 4 2 2 1
# 157	32	0.0	4	28 2 0 1 1
# 158	24	0.0	4	12 3 3 2 4
# 159	20	0.0	4	15 1 1 0 3
# 160	18	0.0	4	13 1 2 2
# 161	22	0.0	4	16 4 0 2
# 162	13	0.0	4	8 2 2 0 1
# 163	25	0.0	4	17 4 2 1 1
# 164	25	0.0	4	19 4 1 0 1
# 165	19	0.0	4	13 4 2
# 166	17	0.0	4	12 2 1 1 1
# 167	16	0.0	4	13 0 0 2 1
# 168	14	0.0	4	10 1 2 1
# 169	13	0.0	4	9 2 1 1
# 170	10	0.0	4	7 1 1 0 1
# 171	11	0.0	4	8 1 2
# 172	7	0.0	4	6 1
# 173	10	0.0	4	9 1
# 174	12	0.0	4	10 2
# 175	17	0.0	4	13 2 0 2
# 176	17	0.0	4	14 3
# 177	26	0.0	4	20 4 0 1 1
# 178	12	0.0	4	8 2 1 1
# 179	10	0.0	4	9 1
# 180	20	0.0	4	14 2 1 2 1
# 181	18	0.0	4	13 3 1 1
# 182	9	0.0	4	5 1 0 1 2
# 183	21	0.0	4	15 3 2 1
# 184	18	0.0	4	15 2 0 0 1
# 185	17	0.0	4	9 3 1 1 3
# 186	20	0.0	4	15 2 1 0 2
# 187	14	0.0	4	8 4 2
# 188	9	0.0	4	5 2 2
# 189	12	0.0	4	9 1 2
# 190	15	0.0	4	10 2 2 0 1
# 191	9	0.0	4	5 1 2 1
# 192	14	0.0	4	7 1 0 6
# 193	8	0.0	4	6 2
# 194	15	0.0	4	10 2 1 1 1
# 195	10	0.0	4	7 2 1
# 196	7	0.0	4	4 0 2 0 1
# 197	12	0.0	4	9 1 0 0 2
# 198	10	0.0	4	6 2 1 0 1
# 199	18	0.0	4	13 2 1 2
# 200	13	0.0	4	6 3 3 0 1
# 201	6	0.0	4	4 0 0 1 1
# 202	11	0.0	4	7 2 0 0 2
# 203	14	0.0	4	8 0 4 0 2
# 204	6	0.0	4	6
# 205	12	0.0	4	8 2 2
# 206	17	0.0	4	12 2 2 0 1
# 207	17	0.0	4	13 3 1
# 208	6	0.0	4	3 1 1 1
# 209	8	0.0	4	7 0 1
# 210	4	0.0	4	3 1
# 211	9	0.0	4	7 0 2
# 212	4	0.0	4	3 0 0 0 1
# 213	19	0.0	4	10 7 1 1
# 214	5	0.0	4	4 1
# 215	34	0.0	4	27 4 2 1
# 216	2	0.0	4	2
# 217	7	0.0	4	3 2 1 0 1
# 218	10	0.0	4	6 3 0 1
# 219	16	0.0	4	10 3 3
# 220	5	0.0	4	3 2
# 221	9	0.0	4	3 2 2 2
# 222	36	0.0	4	15 7 12 1 1
# 223	3	0.0	4	0 3
# 224	3	0.0	4	3
# 225	10	0.0	4	9 1
# 226	8	0.0	4	0 0 0 0 8
# 227	11	0.0	4	0 4 3 2 2
# 228	128	0.0	4	97 17 5 2 7
# 229	4	0.0	4	4
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505057_6_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505057_6_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        19,920 reads @  14.6 µs/read;   4.12 M reads/minute
# Finished in 0.293 s (14.697 µs/read; 4.08 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  19,920
# Reads with adapters:                     9,016 (45.3%)
#
# == Read fate breakdown ==
# Reads that were too short:                  28 (0.1%)
# Reads written (passing filters):        19,892 (99.9%)
#
# Total basepairs processed:     3,245,578 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,486,436 bp (76.6%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 9016 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 1.8%
#   C: 91.1%
#   G: 4.6%
#   T: 2.2%
#   none/other: 0.3%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	25	0.0	2	0 0 0 25
# 14	46	0.0	2	0 0 32 14
# 15	48	0.0	3	0 22 19 7
# 16	22	0.0	3	13 2 5 2
# 17	15	0.0	3	5 6 1 3
# 18	15	0.0	3	4 5 4 2
# 19	8	0.0	3	1 1 2 3 1
# 20	8	0.0	4	3 1 2 2
# 21	3	0.0	4	0 2 0 0 1
# 22	6	0.0	4	1 0 3 1 1
# 23	2	0.0	4	1 0 0 0 1
# 24	6	0.0	4	2 1 0 2 1
# 25	4	0.0	4	3 1
# 26	2	0.0	4	1 0 1
# 27	1	0.0	4	0 0 1
# 28	3	0.0	4	1 0 0 2
# 29	3	0.0	4	0 1 1 1
# 30	2	0.0	4	1 1
# 31	2	0.0	4	0 0 2
# 32	1	0.0	4	1
# 33	3	0.0	4	0 1 1 0 1
# 34	3	0.0	4	2 0 0 0 1
# 35	3	0.0	4	1 2
# 36	1	0.0	4	0 0 0 0 1
# 37	6	0.0	4	5 1
# 38	6	0.0	4	1 1 3 1
# 39	6	0.0	4	4 0 1 1
# 40	27	0.0	4	11 10 5 1
# 41	67	0.0	4	35 13 10 5 4
# 42	19	0.0	4	8 3 2 1 5
# 43	22	0.0	4	10 6 3 2 1
# 44	15	0.0	4	7 4 3 1
# 45	10	0.0	4	5 2 2 0 1
# 46	22	0.0	4	7 8 2 5
# 47	18	0.0	4	5 4 3 5 1
# 48	38	0.0	4	16 12 5 3 2
# 49	35	0.0	4	20 10 2 0 3
# 50	17	0.0	4	5 8 3 1
# 51	23	0.0	4	10 4 4 4 1
# 52	16	0.0	4	11 2 2 1
# 53	14	0.0	4	6 6 1 1
# 54	27	0.0	4	11 9 4 3
# 55	17	0.0	4	11 3 2 1
# 56	22	0.0	4	14 2 4 1 1
# 57	28	0.0	4	8 5 9 4 2
# 58	9	0.0	4	4 1 1 1 2
# 59	8	0.0	4	6 1 0 0 1
# 60	31	0.0	4	7 5 15 2 2
# 61	5	0.0	4	4 1
# 62	38	0.0	4	22 7 5 2 2
# 63	20	0.0	4	12 3 2 1 2
# 64	4	0.0	4	2 0 1 1
# 65	8	0.0	4	7 1
# 66	12	0.0	4	4 5 2 1
# 67	33	0.0	4	20 9 3 0 1
# 68	19	0.0	4	13 5 1
# 69	16	0.0	4	8 6 2
# 70	13	0.0	4	9 2 2
# 71	14	0.0	4	8 4 1 0 1
# 72	16	0.0	4	8 7 0 1
# 73	20	0.0	4	10 8 0 1 1
# 74	26	0.0	4	13 9 1 2 1
# 75	21	0.0	4	15 6
# 76	8	0.0	4	5 2 0 1
# 77	20	0.0	4	15 4 1
# 78	20	0.0	4	14 4 1 0 1
# 79	24	0.0	4	18 6
# 80	18	0.0	4	13 2 2 0 1
# 81	19	0.0	4	15 2 2
# 82	10	0.0	4	9 1
# 83	208	0.0	4	180 16 4 8
# 84	38	0.0	4	34 4
# 85	3398	0.0	4	2884 458 37 14 5
# 86	2863	0.0	4	2435 378 35 9 6
# 87	335	0.0	4	294 36 4 0 1
# 88	22	0.0	4	21 1
# 89	18	0.0	4	12 4 2
# 90	12	0.0	4	10 1 0 1
# 91	4	0.0	4	3 0 0 1
# 92	10	0.0	4	6 2 0 0 2
# 93	14	0.0	4	7 2 1 4
# 94	17	0.0	4	7 5 1 3 1
# 95	25	0.0	4	15 6 2 1 1
# 96	77	0.0	4	59 14 1 2 1
# 97	85	0.0	4	66 15 3 1
# 98	77	0.0	4	65 10 2
# 99	62	0.0	4	50 8 2 2
# 100	52	0.0	4	42 7 2 1
# 101	42	0.0	4	36 5 1
# 102	20	0.0	4	13 7
# 103	27	0.0	4	22 3 0 2
# 104	28	0.0	4	25 2 0 1
# 105	29	0.0	4	27 1 0 1
# 106	22	0.0	4	14 6 1 0 1
# 107	27	0.0	4	20 4 2 0 1
# 108	21	0.0	4	19 2
# 109	13	0.0	4	10 2 0 1
# 110	16	0.0	4	12 2 0 1 1
# 111	8	0.0	4	6 1 0 0 1
# 112	12	0.0	4	8 4
# 113	12	0.0	4	11 0 0 0 1
# 114	13	0.0	4	11 0 1 0 1
# 115	16	0.0	4	14 1 1
# 116	8	0.0	4	7 1
# 117	7	0.0	4	7
# 118	13	0.0	4	9 3 1
# 119	8	0.0	4	8
# 120	5	0.0	4	4 1
# 121	5	0.0	4	4 1
# 122	5	0.0	4	3 1 0 0 1
# 123	7	0.0	4	6 1
# 124	9	0.0	4	7 1 1
# 125	4	0.0	4	4
# 126	3	0.0	4	1 0 1 0 1
# 127	8	0.0	4	8
# 128	5	0.0	4	4 0 0 1
# 129	5	0.0	4	2 2 1
# 130	9	0.0	4	6 1 1 0 1
# 131	9	0.0	4	7 1 0 0 1
# 132	2	0.0	4	2
# 133	4	0.0	4	4
# 134	2	0.0	4	1 1
# 135	8	0.0	4	7 0 0 0 1
# 136	1	0.0	4	0 1
# 137	4	0.0	4	4
# 138	2	0.0	4	1 1
# 139	4	0.0	4	3 1
# 140	1	0.0	4	1
# 141	5	0.0	4	5
# 142	4	0.0	4	4
# 143	3	0.0	4	3
# 144	3	0.0	4	1 1 1
# 145	5	0.0	4	3 2
# 146	3	0.0	4	2 1
# 147	2	0.0	4	2
# 148	4	0.0	4	2 2
# 149	4	0.0	4	2 2
# 150	3	0.0	4	3
# 151	3	0.0	4	1 1 0 0 1
# 152	5	0.0	4	5
# 153	4	0.0	4	3 1
# 154	4	0.0	4	2 2
# 155	3	0.0	4	1 2
# 156	5	0.0	4	3 2
# 157	1	0.0	4	1
# 159	5	0.0	4	3 1 0 1
# 160	3	0.0	4	2 1
# 162	1	0.0	4	1
# 163	1	0.0	4	1
# 164	2	0.0	4	2
# 166	3	0.0	4	1 0 0 0 2
# 167	3	0.0	4	1 2
# 168	2	0.0	4	1 1
# 170	1	0.0	4	1
# 171	1	0.0	4	1
# 172	2	0.0	4	1 1
# 174	2	0.0	4	1 1
# 175	1	0.0	4	1
# 176	1	0.0	4	0 1
# 177	1	0.0	4	1
# 178	3	0.0	4	1 1 0 0 1
# 180	3	0.0	4	3
# 182	1	0.0	4	1
# 183	3	0.0	4	2 0 1
# 184	1	0.0	4	0 0 0 0 1
# 185	2	0.0	4	0 1 1
# 187	1	0.0	4	0 1
# 188	1	0.0	4	1
# 189	9	0.0	4	6 2 1
# 190	2	0.0	4	2
# 191	5	0.0	4	5
# 196	1	0.0	4	1
# 197	2	0.0	4	1 0 0 0 1
# 200	1	0.0	4	1
# 201	1	0.0	4	1
# 203	1	0.0	4	0 0 1
# 205	1	0.0	4	1
# 206	1	0.0	4	1
# 208	1	0.0	4	0 1
# 209	1	0.0	4	0 0 0 1
# 213	1	0.0	4	1
# 216	1	0.0	4	0 0 0 0 1
# 220	1	0.0	4	1
# 224	1	0.0	4	1
# 228	1	0.0	4	0 0 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505058_7_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505058_7_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        58,671 reads @  16.4 µs/read;   3.65 M reads/minute
# Finished in 0.967 s (16.478 µs/read; 3.64 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  58,671
# Reads with adapters:                    10,966 (18.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                 532 (0.9%)
# Reads written (passing filters):        58,139 (99.1%)
#
# Total basepairs processed:    11,712,852 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):     10,844,572 bp (92.6%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 10966 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 1.1%
#   C: 89.8%
#   G: 1.4%
#   T: 2.9%
#   none/other: 4.9%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	25	0.0	2	0 0 0 25
# 14	48	0.0	2	0 0 33 15
# 15	50	0.0	3	0 31 12 7
# 16	46	0.0	3	24 8 8 6
# 17	18	0.0	3	9 5 2 2
# 18	21	0.0	3	10 6 2 3
# 19	14	0.0	3	4 7 3
# 20	5	0.0	4	0 0 2 2 1
# 21	12	0.0	4	1 3 4 3 1
# 22	2	0.0	4	1 0 0 0 1
# 23	1	0.0	4	0 0 0 1
# 24	2	0.0	4	0 1 0 0 1
# 25	1	0.0	4	0 0 0 1
# 26	2	0.0	4	0 0 1 1
# 27	3	0.0	4	2 1
# 28	2	0.0	4	1 1
# 29	2	0.0	4	1 0 0 0 1
# 30	67	0.0	4	60 4 2 1
# 31	4	0.0	4	1 2 0 0 1
# 32	6	0.0	4	4 1 1
# 33	1	0.0	4	0 0 1
# 34	5	0.0	4	2 2 1
# 35	556	0.0	4	489 53 7 6 1
# 36	72	0.0	4	64 6 2
# 37	6	0.0	4	4 1 0 1
# 38	4	0.0	4	1 1 0 0 2
# 39	7	0.0	4	3 2 2
# 40	13	0.0	4	4 2 1 4 2
# 41	66	0.0	4	31 17 7 6 5
# 42	25	0.0	4	7 9 3 4 2
# 43	181	0.0	4	147 20 9 4 1
# 44	23	0.0	4	11 4 2 2 4
# 45	13	0.0	4	5 2 0 1 5
# 46	218	0.0	4	177 31 1 2 7
# 47	43	0.0	4	28 5 4 4 2
# 48	42	0.0	4	16 16 6 2 2
# 49	31	0.0	4	14 7 4 5 1
# 50	15	0.0	4	6 5 0 4
# 51	11	0.0	4	5 1 2 1 2
# 52	4	0.0	4	1 0 1 2
# 53	8	0.0	4	3 1 2 2
# 54	20	0.0	4	13 3 2 2
# 55	23	0.0	4	14 3 2 2 2
# 56	22	0.0	4	7 3 8 2 2
# 57	23	0.0	4	4 1 16 1 1
# 58	11	0.0	4	4 2 3 1 1
# 59	7	0.0	4	5 0 1 1
# 60	61	0.0	4	10 2 37 9 3
# 61	38	0.0	4	28 3 6 1
# 62	42	0.0	4	28 11 2 1
# 63	25	0.0	4	20 2 1 2
# 64	17	0.0	4	10 4 1 1 1
# 65	10	0.0	4	7 1 1 1
# 66	10	0.0	4	6 1 0 2 1
# 67	26	0.0	4	18 4 1 2 1
# 68	10	0.0	4	3 5 0 1 1
# 69	17	0.0	4	12 4 1
# 70	25	0.0	4	14 6 2 3
# 71	18	0.0	4	14 3 0 0 1
# 72	17	0.0	4	11 3 2 0 1
# 73	14	0.0	4	9 2 1 1 1
# 74	17	0.0	4	11 4 1 0 1
# 75	14	0.0	4	8 2 2 2
# 76	20	0.0	4	10 4 3 1 2
# 77	10	0.0	4	10
# 78	19	0.0	4	16 2 1
# 79	23	0.0	4	22 1
# 80	6	0.0	4	5 0 1
# 81	4	0.0	4	1 3
# 82	6	0.0	4	6
# 83	6089	0.0	4	5469 548 46 17 9
# 84	933	0.0	4	846 86 1
# 85	461	0.0	4	413 39 7 1 1
# 86	53	0.0	4	47 5 0 0 1
# 87	21	0.0	4	15 0 2 1 3
# 88	4	0.0	4	3 1
# 89	5	0.0	4	2 2 0 1
# 90	9	0.0	4	1 3 3 1 1
# 91	10	0.0	4	4 3 0 1 2
# 92	22	0.0	4	11 3 4 1 3
# 93	13	0.0	4	2 4 1 1 5
# 94	13	0.0	4	4 2 1 0 6
# 95	31	0.0	4	13 12 3 0 3
# 96	88	0.0	4	59 17 4 1 7
# 97	75	0.0	4	59 14 1 1
# 98	61	0.0	4	53 6 0 0 2
# 99	51	0.0	4	42 9
# 100	35	0.0	4	29 5 0 0 1
# 101	31	0.0	4	19 10 0 1 1
# 102	31	0.0	4	24 5 0 0 2
# 103	34	0.0	4	27 5 0 0 2
# 104	29	0.0	4	22 5 0 1 1
# 105	20	0.0	4	13 5 2
# 106	29	0.0	4	18 7 2 1 1
# 107	26	0.0	4	16 7 1 0 2
# 108	12	0.0	4	10 1 0 0 1
# 109	21	0.0	4	13 3 2 1 2
# 110	10	0.0	4	6 3 0 0 1
# 111	17	0.0	4	12 1 1 0 3
# 112	19	0.0	4	11 7 1
# 113	17	0.0	4	9 2 1 1 4
# 114	16	0.0	4	10 5 0 0 1
# 115	17	0.0	4	13 2 0 0 2
# 116	13	0.0	4	12 0 0 1
# 117	6	0.0	4	6
# 118	11	0.0	4	7 2 0 0 2
# 119	10	0.0	4	6 2 1 0 1
# 120	12	0.0	4	8 3 1
# 121	12	0.0	4	6 4 0 0 2
# 122	11	0.0	4	5 4 1 0 1
# 123	10	0.0	4	9 0 0 0 1
# 124	11	0.0	4	8 1 0 1 1
# 125	6	0.0	4	4 2
# 126	14	0.0	4	11 2 0 0 1
# 127	4	0.0	4	3 1
# 128	10	0.0	4	8 2
# 129	5	0.0	4	2 2 1
# 130	4	0.0	4	2 1 0 0 1
# 131	7	0.0	4	3 4
# 132	6	0.0	4	5 1
# 133	6	0.0	4	3 2 1
# 134	4	0.0	4	2 0 1 0 1
# 135	10	0.0	4	5 4 0 0 1
# 136	6	0.0	4	4 0 1 0 1
# 137	4	0.0	4	3 0 1
# 138	5	0.0	4	4 1
# 139	8	0.0	4	4 3 0 0 1
# 140	7	0.0	4	3 3 0 0 1
# 141	6	0.0	4	3 2 0 0 1
# 142	4	0.0	4	3 0 1
# 143	6	0.0	4	3 3
# 144	8	0.0	4	3 4 0 0 1
# 145	4	0.0	4	3 0 0 0 1
# 146	5	0.0	4	1 2 0 0 2
# 147	7	0.0	4	4 2 0 0 1
# 148	2	0.0	4	2
# 149	4	0.0	4	3 1
# 150	11	0.0	4	4 2 1 0 4
# 151	3	0.0	4	1 1 0 1
# 152	4	0.0	4	1 2 0 0 1
# 153	4	0.0	4	3 1
# 154	2	0.0	4	2
# 155	2	0.0	4	2
# 156	3	0.0	4	3
# 157	3	0.0	4	2 1
# 158	2	0.0	4	1 1
# 159	1	0.0	4	1
# 160	1	0.0	4	1
# 161	4	0.0	4	3 0 0 0 1
# 162	5	0.0	4	4 1
# 163	2	0.0	4	1 0 1
# 164	4	0.0	4	3 0 0 0 1
# 165	1	0.0	4	1
# 166	3	0.0	4	2 0 0 1
# 167	3	0.0	4	2 1
# 168	2	0.0	4	2
# 169	2	0.0	4	2
# 170	2	0.0	4	0 1 1
# 171	1	0.0	4	1
# 172	2	0.0	4	2
# 173	3	0.0	4	2 1
# 174	2	0.0	4	2
# 175	2	0.0	4	2
# 176	4	0.0	4	1 3
# 177	2	0.0	4	1 1
# 178	2	0.0	4	0 1 0 1
# 179	2	0.0	4	2
# 180	4	0.0	4	2 0 0 0 2
# 181	3	0.0	4	3
# 182	1	0.0	4	1
# 183	3	0.0	4	2 0 0 0 1
# 184	2	0.0	4	1 1
# 185	3	0.0	4	2 0 0 0 1
# 187	1	0.0	4	1
# 188	5	0.0	4	4 0 1
# 189	7	0.0	4	6 0 0 1
# 190	5	0.0	4	5
# 191	1	0.0	4	1
# 192	1	0.0	4	1
# 194	3	0.0	4	2 1
# 195	2	0.0	4	1 1
# 197	2	0.0	4	1 1
# 198	1	0.0	4	0 0 0 0 1
# 199	3	0.0	4	0 3
# 200	2	0.0	4	2
# 201	1	0.0	4	1
# 202	1	0.0	4	1
# 204	1	0.0	4	1
# 206	1	0.0	4	0 0 0 0 1
# 207	2	0.0	4	1 1
# 208	1	0.0	4	1
# 209	1	0.0	4	1
# 210	1	0.0	4	0 0 0 0 1
# 211	1	0.0	4	1
# 213	2	0.0	4	1 1
# 214	3	0.0	4	2 0 1
# 216	2	0.0	4	0 2
# 217	2	0.0	4	1 0 0 0 1
# 218	2	0.0	4	2
# 219	1	0.0	4	0 1
# 221	10	0.0	4	10
# 222	2	0.0	4	2
# 223	2	0.0	4	2
# 224	1	0.0	4	0 1
# 225	1	0.0	4	1
# 228	12	0.0	4	4 3 2 1 2
# 229	2	0.0	4	1 0 0 0 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505059_8_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505059_8_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        38,078 reads @  15.6 µs/read;   3.84 M reads/minute
# Finished in 0.597 s (15.687 µs/read; 3.82 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  38,078
# Reads with adapters:                    15,142 (39.8%)
#
# == Read fate breakdown ==
# Reads that were too short:                 735 (1.9%)
# Reads written (passing filters):        37,343 (98.1%)
#
# Total basepairs processed:     6,051,731 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      5,389,761 bp (89.1%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 15142 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 3.6%
#   C: 77.6%
#   G: 9.7%
#   T: 4.2%
#   none/other: 4.9%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	5888	0.0	2	0 0 0 5888
# 14	3860	0.0	2	0 0 3685 175
# 15	121	0.0	3	0 84 22 15
# 16	25	0.0	3	14 3 4 4
# 17	24	0.0	3	15 3 2 4
# 18	22	0.0	3	5 10 3 4
# 19	13	0.0	3	6 1 4 2
# 20	15	0.0	4	1 7 0 4 3
# 21	12	0.0	4	2 4 3 1 2
# 22	6	0.0	4	1 1 1 0 3
# 23	3	0.0	4	3
# 24	3	0.0	4	2 0 0 1
# 25	14	0.0	4	11 3
# 26	1	0.0	4	1
# 27	3	0.0	4	1 0 0 1 1
# 28	5	0.0	4	1 1 2 0 1
# 29	6	0.0	4	2 1 3
# 30	217	0.0	4	191 20 2 4
# 31	5	0.0	4	3 1 0 0 1
# 32	2	0.0	4	1 1
# 33	5	0.0	4	0 1 2 1 1
# 34	4	0.0	4	0 1 2 1
# 35	3	0.0	4	0 2 0 1
# 36	2	0.0	4	0 0 1 0 1
# 37	6	0.0	4	1 1 0 1 3
# 38	5	0.0	4	2 0 2 1
# 39	6	0.0	4	0 2 2 1 1
# 40	16	0.0	4	3 3 3 6 1
# 41	42	0.0	4	12 13 9 4 4
# 42	20	0.0	4	7 5 4 3 1
# 43	9	0.0	4	3 3 0 2 1
# 44	14	0.0	4	3 1 5 4 1
# 45	10	0.0	4	5 0 2 2 1
# 46	17	0.0	4	6 3 3 4 1
# 47	25	0.0	4	10 2 5 6 2
# 48	34	0.0	4	13 6 6 5 4
# 49	38	0.0	4	10 11 5 5 7
# 50	13	0.0	4	5 5 1 0 2
# 51	15	0.0	4	3 4 5 1 2
# 52	4	0.0	4	2 0 1 1
# 53	12	0.0	4	4 4 2 2
# 54	10	0.0	4	5 3 2
# 55	2	0.0	4	0 0 1 1
# 56	15	0.0	4	5 1 3 3 3
# 57	22	0.0	4	5 2 7 5 3
# 58	10	0.0	4	3 2 4 1
# 59	14	0.0	4	4 5 4 1
# 60	85	0.0	4	9 6 60 9 1
# 61	19	0.0	4	10 2 3 2 2
# 62	63	0.0	4	41 10 6 3 3
# 63	18	0.0	4	8 3 5 1 1
# 64	8	0.0	4	5 2 1
# 65	10	0.0	4	4 3 1 1 1
# 66	7	0.0	4	1 3 1 1 1
# 67	7	0.0	4	3 2 1 1
# 68	8	0.0	4	3 3 1 0 1
# 69	8	0.0	4	3 2 0 1 2
# 70	9	0.0	4	4 2 1 1 1
# 71	9	0.0	4	2 1 3 2 1
# 72	7	0.0	4	3 3 1
# 73	12	0.0	4	7 2 1 0 2
# 74	25	0.0	4	6 7 6 5 1
# 75	14	0.0	4	9 4 1
# 76	5	0.0	4	1 2 1 1
# 77	11	0.0	4	7 3 1
# 78	6	0.0	4	5 1
# 79	6	0.0	4	4 0 2
# 80	2	0.0	4	1 0 0 0 1
# 81	11	0.0	4	6 4 0 1
# 82	1	0.0	4	0 1
# 83	55	0.0	4	37 12 4 2
# 84	5	0.0	4	4 0 1
# 85	66	0.0	4	47 14 4 1
# 86	83	0.0	4	74 6 2 0 1
# 87	6	0.0	4	2 0 1 1 2
# 88	6	0.0	4	1 1 0 2 2
# 89	31	0.0	4	22 2 3 3 1
# 90	33	0.0	4	20 4 3 4 2
# 91	42	0.0	4	18 6 2 6 10
# 92	64	0.0	4	30 7 3 9 15
# 93	75	0.0	4	28 8 4 11 24
# 94	79	0.0	4	25 7 11 24 12
# 95	131	0.0	4	63 30 10 17 11
# 96	275	0.0	4	211 27 8 18 11
# 97	315	0.0	4	254 25 12 13 11
# 98	193	0.0	4	164 14 4 3 8
# 99	226	0.0	4	182 20 7 8 9
# 100	133	0.0	4	106 11 4 6 6
# 101	123	0.0	4	91 15 6 6 5
# 102	111	0.0	4	85 14 1 6 5
# 103	118	0.0	4	90 18 2 5 3
# 104	98	0.0	4	74 17 1 3 3
# 105	93	0.0	4	68 10 5 5 5
# 106	71	0.0	4	55 5 2 3 6
# 107	79	0.0	4	60 11 1 3 4
# 108	67	0.0	4	50 8 3 1 5
# 109	60	0.0	4	41 11 0 3 5
# 110	48	0.0	4	37 4 0 4 3
# 111	53	0.0	4	41 4 2 1 5
# 112	61	0.0	4	44 6 2 2 7
# 113	46	0.0	4	37 3 3 2 1
# 114	54	0.0	4	40 2 3 5 4
# 115	40	0.0	4	31 4 2 0 3
# 116	39	0.0	4	27 3 2 2 5
# 117	40	0.0	4	32 1 0 2 5
# 118	33	0.0	4	25 4 0 2 2
# 119	24	0.0	4	16 0 2 4 2
# 120	28	0.0	4	18 2 2 2 4
# 121	32	0.0	4	18 1 2 2 9
# 122	22	0.0	4	14 1 1 3 3
# 123	34	0.0	4	19 1 2 7 5
# 124	27	0.0	4	17 2 1 2 5
# 125	31	0.0	4	23 1 1 3 3
# 126	18	0.0	4	12 3 0 1 2
# 127	15	0.0	4	10 1 0 1 3
# 128	21	0.0	4	9 3 0 5 4
# 129	20	0.0	4	15 2 0 1 2
# 130	18	0.0	4	13 0 1 2 2
# 131	14	0.0	4	10 2 1 0 1
# 132	22	0.0	4	16 4 0 1 1
# 133	19	0.0	4	10 4 0 2 3
# 134	18	0.0	4	14 2 0 0 2
# 135	18	0.0	4	16 0 0 0 2
# 136	8	0.0	4	7 0 0 1
# 137	16	0.0	4	10 2 0 1 3
# 138	22	0.0	4	11 1 3 3 4
# 139	24	0.0	4	14 7 1 1 1
# 140	17	0.0	4	9 0 2 2 4
# 141	13	0.0	4	10 1 0 1 1
# 142	16	0.0	4	12 1 1 2
# 143	18	0.0	4	12 2 2 0 2
# 144	18	0.0	4	11 4 0 2 1
# 145	18	0.0	4	14 2 0 2
# 146	18	0.0	4	9 4 0 1 4
# 147	18	0.0	4	9 3 0 1 5
# 148	15	0.0	4	12 0 0 2 1
# 149	15	0.0	4	8 2 0 2 3
# 150	13	0.0	4	7 3 0 1 2
# 151	11	0.0	4	7 1 1 0 2
# 152	10	0.0	4	8 0 0 2
# 153	18	0.0	4	11 1 1 3 2
# 154	7	0.0	4	5 1 0 1
# 155	8	0.0	4	2 1 0 3 2
# 156	14	0.0	4	8 3 0 1 2
# 157	8	0.0	4	4 2 0 1 1
# 158	11	0.0	4	7 1 1 0 2
# 159	15	0.0	4	10 1 1 1 2
# 160	13	0.0	4	8 1 1 1 2
# 161	8	0.0	4	5 0 2 1
# 162	7	0.0	4	4 1 1 1
# 163	8	0.0	4	4 1 0 1 2
# 164	8	0.0	4	2 0 0 4 2
# 165	5	0.0	4	2 1 0 0 2
# 166	5	0.0	4	3 1 0 0 1
# 167	11	0.0	4	6 2 1 2
# 168	14	0.0	4	9 0 0 4 1
# 169	8	0.0	4	7 0 0 0 1
# 170	3	0.0	4	3
# 171	11	0.0	4	5 2 2 0 2
# 172	4	0.0	4	0 3 0 0 1
# 173	6	0.0	4	4 1 0 0 1
# 174	6	0.0	4	1 2 0 2 1
# 175	1	0.0	4	1
# 176	2	0.0	4	1 1
# 177	10	0.0	4	6 2 0 2
# 178	7	0.0	4	3 2 0 1 1
# 179	5	0.0	4	3 0 1 0 1
# 180	3	0.0	4	2 0 0 1
# 181	3	0.0	4	2 0 0 0 1
# 182	5	0.0	4	3 1 0 1
# 183	10	0.0	4	6 2 0 0 2
# 184	9	0.0	4	6 0 0 0 3
# 185	10	0.0	4	4 2 0 0 4
# 186	6	0.0	4	3 0 0 1 2
# 187	3	0.0	4	1 1 0 0 1
# 188	3	0.0	4	2 0 0 0 1
# 189	23	0.0	4	14 4 2 2 1
# 190	11	0.0	4	8 1 1 0 1
# 191	6	0.0	4	5 0 0 1
# 192	7	0.0	4	4 1 0 0 2
# 193	3	0.0	4	1 1 0 0 1
# 194	4	0.0	4	3 0 0 1
# 195	2	0.0	4	1 0 0 1
# 196	4	0.0	4	1 1 1 1
# 197	1	0.0	4	0 0 0 0 1
# 198	2	0.0	4	1 1
# 199	4	0.0	4	2 0 0 1 1
# 200	3	0.0	4	1 0 0 1 1
# 201	1	0.0	4	1
# 202	6	0.0	4	3 1 1 1
# 203	1	0.0	4	0 0 0 0 1
# 204	1	0.0	4	0 0 0 1
# 205	6	0.0	4	2 0 0 0 4
# 206	4	0.0	4	1 0 0 2 1
# 207	6	0.0	4	4 2
# 208	1	0.0	4	1
# 209	7	0.0	4	3 0 1 0 3
# 210	4	0.0	4	0 1 0 1 2
# 211	5	0.0	4	5
# 212	11	0.0	4	7 2 0 1 1
# 213	2	0.0	4	2
# 214	1	0.0	4	0 1
# 215	1	0.0	4	1
# 216	3	0.0	4	2 0 1
# 217	1	0.0	4	1
# 219	4	0.0	4	2 0 0 1 1
# 220	3	0.0	4	3
# 221	2	0.0	4	2
# 222	7	0.0	4	7
# 223	8	0.0	4	5 2 1
# 224	1	0.0	4	0 1
# 225	3	0.0	4	1 2
# 226	2	0.0	4	1 1
# 227	6	0.0	4	4 1 0 0 1
# 228	28	0.0	4	4 0 1 9 14
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505060_9_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505060_9_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        17,596 reads @  13.3 µs/read;   4.50 M reads/minute
# Finished in 0.237 s (13.466 µs/read; 4.46 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  17,596
# Reads with adapters:                     1,524 (8.7%)
#
# == Read fate breakdown ==
# Reads that were too short:                  39 (0.2%)
# Reads written (passing filters):        17,557 (99.8%)
#
# Total basepairs processed:     2,209,659 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,113,846 bp (95.7%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 1524 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 9.1%
#   C: 50.7%
#   G: 9.3%
#   T: 28.4%
#   none/other: 2.6%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	42	0.0	2	0 0 0 42
# 14	117	0.0	2	0 0 103 14
# 15	30	0.0	3	0 14 10 6
# 16	19	0.0	3	9 5 3 2
# 17	27	0.0	3	12 4 6 5
# 18	12	0.0	3	2 5 4 1
# 19	41	0.0	3	33 6 2
# 20	7	0.0	4	0 2 2 1 2
# 21	7	0.0	4	1 0 0 2 4
# 22	9	0.0	4	3 1 1 1 3
# 23	4	0.0	4	0 1 0 1 2
# 24	4	0.0	4	1 0 2 1
# 25	6	0.0	4	1 4 0 1
# 26	3	0.0	4	1 0 2
# 27	2	0.0	4	0 0 0 1 1
# 28	3	0.0	4	0 1 0 1 1
# 29	4	0.0	4	0 0 2 1 1
# 30	2	0.0	4	0 1 0 0 1
# 31	4	0.0	4	1 1 1 1
# 32	1	0.0	4	0 0 1
# 34	1	0.0	4	1
# 35	3	0.0	4	1 0 2
# 36	5	0.0	4	2 0 2 0 1
# 37	1	0.0	4	0 0 1
# 38	3	0.0	4	0 1 0 1 1
# 39	2	0.0	4	2
# 40	19	0.0	4	7 4 3 3 2
# 41	32	0.0	4	9 7 5 8 3
# 42	10	0.0	4	4 2 0 2 2
# 43	9	0.0	4	1 1 4 1 2
# 44	2	0.0	4	1 0 0 0 1
# 45	10	0.0	4	2 2 3 1 2
# 46	10	0.0	4	1 1 1 3 4
# 47	15	0.0	4	4 0 4 5 2
# 48	21	0.0	4	10 3 4 3 1
# 49	23	0.0	4	6 4 7 3 3
# 50	23	0.0	4	19 0 3 1
# 51	6	0.0	4	2 2 0 1 1
# 52	6	0.0	4	0 1 2 1 2
# 53	5	0.0	4	0 0 3 1 1
# 54	6	0.0	4	2 0 1 3
# 55	10	0.0	4	1 3 1 4 1
# 56	31	0.0	4	2 1 22 4 2
# 57	66	0.0	4	3 3 52 5 3
# 58	17	0.0	4	6 1 8 1 1
# 59	8	0.0	4	1 2 2 3
# 60	82	0.0	4	6 5 62 8 1
# 61	10	0.0	4	3 3 3 1
# 62	32	0.0	4	21 5 5 1
# 63	6	0.0	4	4 1 0 0 1
# 64	32	0.0	4	23 4 5
# 65	5	0.0	4	2 2 0 0 1
# 66	3	0.0	4	1 0 1 0 1
# 67	13	0.0	4	6 1 3 2 1
# 68	4	0.0	4	1 1 1 1
# 69	3	0.0	4	2 0 0 0 1
# 70	4	0.0	4	1 2 0 1
# 71	4	0.0	4	3 0 0 0 1
# 72	1	0.0	4	0 1
# 73	7	0.0	4	2 1 3 0 1
# 74	9	0.0	4	4 3 2
# 75	8	0.0	4	4 2 1 0 1
# 76	1	0.0	4	0 1
# 77	4	0.0	4	2 1 1
# 78	4	0.0	4	0 2 0 1 1
# 79	8	0.0	4	6 0 2
# 80	6	0.0	4	2 1 2 0 1
# 81	4	0.0	4	3 1
# 82	1	0.0	4	1
# 83	127	0.0	4	99 20 4 2 2
# 84	4	0.0	4	3 1
# 85	87	0.0	4	60 16 7 3 1
# 86	124	0.0	4	6 86 29 3
# 87	6	0.0	4	3 2 1
# 88	2	0.0	4	1 1
# 89	8	0.0	4	3 3 0 2
# 90	5	0.0	4	3 2
# 91	1	0.0	4	0 1
# 92	14	0.0	4	10 4
# 93	4	0.0	4	3 1
# 94	6	0.0	4	5 0 0 0 1
# 95	12	0.0	4	8 4
# 96	16	0.0	4	14 1 0 1
# 97	16	0.0	4	13 1 1 1
# 98	13	0.0	4	11 1 1
# 99	6	0.0	4	4 2
# 100	5	0.0	4	5
# 101	10	0.0	4	7 1 1 1
# 102	7	0.0	4	6 0 0 0 1
# 103	4	0.0	4	3 0 0 1
# 104	6	0.0	4	4 1 0 1
# 105	6	0.0	4	5 1
# 106	5	0.0	4	4 1
# 107	4	0.0	4	3 1
# 108	2	0.0	4	1 1
# 109	4	0.0	4	1 2 0 1
# 110	2	0.0	4	2
# 111	2	0.0	4	2
# 112	6	0.0	4	2 3 0 1
# 113	2	0.0	4	1 0 0 0 1
# 114	1	0.0	4	0 1
# 115	4	0.0	4	4
# 116	1	0.0	4	0 1
# 117	6	0.0	4	4 1 1
# 119	2	0.0	4	1 0 1
# 120	1	0.0	4	0 0 0 1
# 121	1	0.0	4	0 0 0 0 1
# 122	3	0.0	4	2 0 0 1
# 123	1	0.0	4	1
# 124	2	0.0	4	1 1
# 126	2	0.0	4	2
# 129	1	0.0	4	0 0 0 1
# 131	1	0.0	4	0 0 0 1
# 132	1	0.0	4	1
# 135	1	0.0	4	0 0 0 0 1
# 136	1	0.0	4	1
# 137	1	0.0	4	0 0 0 0 1
# 138	1	0.0	4	0 0 0 1
# 139	1	0.0	4	1
# 140	2	0.0	4	2
# 141	3	0.0	4	2 0 0 1
# 143	2	0.0	4	1 0 0 1
# 146	1	0.0	4	1
# 147	2	0.0	4	0 0 2
# 149	2	0.0	4	2
# 150	1	0.0	4	1
# 151	2	0.0	4	2
# 152	1	0.0	4	0 1
# 154	1	0.0	4	1
# 156	1	0.0	4	0 0 0 1
# 165	1	0.0	4	1
# 180	1	0.0	4	1
# 187	1	0.0	4	1
# 190	1	0.0	4	1
# 191	1	0.0	4	1
# 192	1	0.0	4	1
# 193	1	0.0	4	1
# 199	1	0.0	4	1
# 201	1	0.0	4	1
# 202	1	0.0	4	0 0 0 1
# 203	1	0.0	4	0 0 1
# 208	1	0.0	4	1
# 212	1	0.0	4	1
# 214	1	0.0	4	0 0 0 1
# 219	1	0.0	4	0 0 0 1
# 221	1	0.0	4	0 0 0 1
# 224	1	0.0	4	0 1
# 228	2	0.0	4	1 1
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505061_10_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505061_10_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:01        75,787 reads @  15.1 µs/read;   3.97 M reads/minute
# Finished in 1.147 s (15.131 µs/read; 3.97 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  75,787
# Reads with adapters:                    70,039 (92.4%)
#
# == Read fate breakdown ==
# Reads that were too short:               9,598 (12.7%)
# Reads written (passing filters):        66,189 (87.3%)
#
# Total basepairs processed:    14,323,031 bp
# ...
# 103	33	0.0	4	28 4 0 0 1
# 104	31	0.0	4	23 6 1 0 1
# 105	40	0.0	4	27 11 1 0 1
# 106	25	0.0	4	16 5 3 1
# 107	30	0.0	4	24 5 1
# 108	31	0.0	4	28 2 1
# 109	23	0.0	4	17 4 1 1
# 110	26	0.0	4	20 4 1 1
# 111	22	0.0	4	19 2 0 1
# 112	29	0.0	4	24 5
# 113	18	0.0	4	16 0 1 1
# 114	18	0.0	4	12 4 2
# 115	18	0.0	4	14 2 1 1
# 116	12	0.0	4	9 2 0 0 1
# 117	13	0.0	4	7 4 0 1 1
# 118	7	0.0	4	7
# 119	8	0.0	4	6 1 0 0 1
# 120	10	0.0	4	7 1 1 0 1
# 121	10	0.0	4	8 0 1 1
# 122	5	0.0	4	4 0 1
# 123	10	0.0	4	7 2 1
# 124	8	0.0	4	6 0 1 1
# 125	14	0.0	4	11 3
# 126	14	0.0	4	14
# 127	11	0.0	4	8 3
# 128	9	0.0	4	5 2 2
# 129	10	0.0	4	4 5 0 1
# 130	5	0.0	4	3 1 1
# 131	6	0.0	4	6
# 132	6	0.0	4	2 3 1
# 133	6	0.0	4	6
# 134	10	0.0	4	10
# 135	3	0.0	4	2 1
# 136	6	0.0	4	4 2
# 137	5	0.0	4	3 2
# 138	6	0.0	4	4 1 1
# 139	4	0.0	4	2 0 1 1
# 140	8	0.0	4	6 2
# 141	6	0.0	4	5 1
# 142	4	0.0	4	2 2
# 143	2	0.0	4	1 1
# 144	5	0.0	4	3 1 0 1
# 145	8	0.0	4	6 2
# 146	4	0.0	4	2 0 1 0 1
# 147	5	0.0	4	4 1
# 148	5	0.0	4	3 1 0 1
# 149	3	0.0	4	2 0 1
# 150	5	0.0	4	3 2
# 151	2	0.0	4	1 1
# 152	1	0.0	4	0 1
# 153	6	0.0	4	3 2 0 1
# 154	8	0.0	4	6 2
# 155	2	0.0	4	2
# 156	4	0.0	4	2 1 1
# 157	4	0.0	4	4
# 158	5	0.0	4	2 3
# 159	2	0.0	4	2
# 160	6	0.0	4	5 1
# 161	7	0.0	4	6 1
# 162	4	0.0	4	4
# 163	4	0.0	4	2 2
# 164	2	0.0	4	1 0 0 0 1
# 165	4	0.0	4	4
# 166	3	0.0	4	3
# 168	2	0.0	4	0 2
# 169	2	0.0	4	2
# 171	1	0.0	4	1
# 172	5	0.0	4	4 0 1
# 173	6	0.0	4	5 1
# 174	1	0.0	4	1
# 175	4	0.0	4	2 1 0 0 1
# 177	4	0.0	4	4
# 178	1	0.0	4	0 1
# 179	2	0.0	4	0 2
# 180	2	0.0	4	2
# 181	2	0.0	4	1 1
# 182	2	0.0	4	1 1
# 183	2	0.0	4	1 0 1
# 184	1	0.0	4	1
# 186	3	0.0	4	3
# 188	2	0.0	4	2
# 189	13	0.0	4	9 2 1 0 1
# 190	19	0.0	4	14 3 1 1
# 191	7	0.0	4	3 3 1
# 192	8	0.0	4	4 1 3
# 193	2	0.0	4	0 2
# 194	1	0.0	4	1
# 196	2	0.0	4	2
# 197	1	0.0	4	1
# 199	1	0.0	4	1
# 203	2	0.0	4	1 0 0 0 1
# 205	1	0.0	4	1
# 206	1	0.0	4	0 0 1
# 207	2	0.0	4	2
# 210	1	0.0	4	1
# 212	2	0.0	4	1 0 1
# 218	1	0.0	4	0 0 0 1
# 220	3	0.0	4	1 1 0 0 1
# 222	4	0.0	4	4
# 223	1	0.0	4	0 1
# 225	8	0.0	4	7 1
# 228	3	0.0	4	0 0 2 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505154_103_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505154_103_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        18,687 reads @  15.6 µs/read;   3.85 M reads/minute
# Finished in 0.293 s (15.690 µs/read; 3.82 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  18,687
# Reads with adapters:                     8,340 (44.6%)
#
# == Read fate breakdown ==
# Reads that were too short:                  44 (0.2%)
# Reads written (passing filters):        18,643 (99.8%)
#
# Total basepairs processed:     3,210,719 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      2,519,431 bp (78.5%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 8340 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 1.8%
#   C: 95.3%
#   G: 1.0%
#   T: 1.4%
#   none/other: 0.5%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	2	0.0	2	0 0 0 2
# 14	5	0.0	2	0 0 3 2
# 15	10	0.0	3	0 5 5
# 16	8	0.0	3	3 3 0 2
# 17	14	0.0	3	8 4 0 2
# 18	43	0.0	3	21 10 7 5
# 19	27	0.0	3	13 7 5 2
# 20	20	0.0	4	11 6 0 2 1
# 21	8	0.0	4	3 1 2 1 1
# 22	15	0.0	4	6 4 2 2 1
# 23	4	0.0	4	0 2 0 1 1
# 24	6	0.0	4	0 2 1 1 2
# 25	3	0.0	4	0 0 0 1 2
# 27	8	0.0	4	5 1 1 0 1
# 30	1	0.0	4	0 1
# 32	1	0.0	4	0 1
# 33	1	0.0	4	0 0 0 1
# 34	1	0.0	4	1
# 35	4	0.0	4	0 0 1 1 2
# 36	14	0.0	4	2 2 4 3 3
# 37	3	0.0	4	0 0 1 1 1
# 38	5	0.0	4	0 0 1 3 1
# 39	1	0.0	4	0 0 0 1
# 40	3	0.0	4	1 0 1 1
# 41	15	0.0	4	8 2 2 2 1
# 42	9	0.0	4	2 5 1 0 1
# 43	77	0.0	4	39 20 9 7 2
# 44	4	0.0	4	1 1 1 1
# 45	2	0.0	4	1 0 1
# 46	4	0.0	4	1 1 1 1
# 47	5	0.0	4	3 0 1 0 1
# 48	38	0.0	4	21 9 5 1 2
# 49	10	0.0	4	6 2 0 1 1
# 50	5	0.0	4	3 1 0 0 1
# 51	9	0.0	4	3 2 1 1 2
# 52	7	0.0	4	4 2 0 0 1
# 53	8	0.0	4	2 1 1 2 2
# 54	15	0.0	4	9 2 2 0 2
# 55	9	0.0	4	3 3 3
# 56	5	0.0	4	2 1 2
# 57	57	0.0	4	37 11 5 2 2
# 58	22	0.0	4	8 7 2 3 2
# 59	3	0.0	4	3
# 61	3	0.0	4	0 0 2 1
# 62	6	0.0	4	3 0 1 1 1
# 63	21	0.0	4	9 7 1 2 2
# 64	7	0.0	4	0 3 1 1 2
# 65	6	0.0	4	1 3 1 0 1
# 67	9	0.0	4	7 0 1 0 1
# 68	4	0.0	4	2 0 1 1
# 69	8	0.0	4	5 3
# 70	40	0.0	4	29 5 3 3
# 71	17	0.0	4	7 7 1 1 1
# 72	18	0.0	4	9 4 2 1 2
# 73	39	0.0	4	26 7 3 2 1
# 74	105	0.0	4	73 19 8 4 1
# 75	105	0.0	4	71 25 4 2 3
# 76	37	0.0	4	24 10 0 1 2
# 77	54	0.0	4	35 15 4
# 78	33	0.0	4	24 4 2 3
# 79	35	0.0	4	26 5 1 2 1
# 80	23	0.0	4	16 7
# 81	25	0.0	4	20 3 1 0 1
# 82	16	0.0	4	11 5
# 83	1242	0.0	4	1012 188 27 8 7
# 84	191	0.0	4	168 21 1 0 1
# 85	922	0.0	4	794 108 14 6
# 86	4059	0.0	4	3486 462 81 26 4
# 87	509	0.0	4	432 67 6 3 1
# 88	41	0.0	4	37 2 2
# 89	4	0.0	4	4
# 90	3	0.0	4	2 0 1
# 91	4	0.0	4	2 0 0 0 2
# 92	1	0.0	4	0 0 1
# 93	3	0.0	4	1 0 0 1 1
# 94	4	0.0	4	3 0 0 0 1
# 95	6	0.0	4	1 1 0 3 1
# 96	8	0.0	4	5 1 0 0 2
# 97	7	0.0	4	3 1 1 1 1
# 98	10	0.0	4	7 1 0 1 1
# 99	5	0.0	4	3 2
# 100	7	0.0	4	5 2
# 101	3	0.0	4	3
# 102	5	0.0	4	4 1
# 103	15	0.0	4	12 3
# 104	10	0.0	4	10
# 105	6	0.0	4	4 2
# 106	2	0.0	4	1 1
# 107	2	0.0	4	1 0 0 1
# 108	1	0.0	4	1
# 109	5	0.0	4	3 1 0 0 1
# 110	1	0.0	4	1
# 111	3	0.0	4	3
# 112	1	0.0	4	1
# 113	4	0.0	4	2 1 0 1
# 114	6	0.0	4	4 1 0 0 1
# 115	2	0.0	4	1 0 0 1
# 116	2	0.0	4	2
# 117	4	0.0	4	2 0 0 2
# 118	3	0.0	4	2 0 0 0 1
# 119	6	0.0	4	3 1 0 1 1
# 120	2	0.0	4	2
# 121	4	0.0	4	2 1 0 1
# 122	2	0.0	4	1 1
# 123	3	0.0	4	2 0 0 0 1
# 124	3	0.0	4	2 0 0 0 1
# 125	5	0.0	4	3 2
# 126	3	0.0	4	1 1 0 1
# 127	1	0.0	4	1
# 128	2	0.0	4	1 0 0 0 1
# 129	4	0.0	4	0 3 1
# 130	1	0.0	4	0 1
# 131	4	0.0	4	4
# 132	2	0.0	4	2
# 134	6	0.0	4	4 2
# 135	5	0.0	4	3 2
# 136	5	0.0	4	1 2 2
# 139	3	0.0	4	1 0 1 0 1
# 143	2	0.0	4	0 0 0 0 2
# 144	2	0.0	4	1 1
# 145	1	0.0	4	0 0 0 0 1
# 147	2	0.0	4	2
# 149	1	0.0	4	0 0 1
# 151	1	0.0	4	1
# 152	2	0.0	4	0 1 0 1
# 153	1	0.0	4	0 0 0 0 1
# 154	2	0.0	4	0 0 0 0 2
# 155	2	0.0	4	0 1 0 0 1
# 159	1	0.0	4	1
# 162	3	0.0	4	1 0 0 0 2
# 163	1	0.0	4	1
# 164	2	0.0	4	1 0 0 1
# 166	2	0.0	4	2
# 169	1	0.0	4	1
# 170	1	0.0	4	0 0 0 0 1
# 172	1	0.0	4	1
# 173	2	0.0	4	0 0 0 1 1
# 174	1	0.0	4	0 1
# 175	1	0.0	4	0 1
# 182	2	0.0	4	1 0 1
# 184	1	0.0	4	1
# 185	2	0.0	4	1 1
# 187	1	0.0	4	0 1
# 189	1	0.0	4	1
# 193	1	0.0	4	0 1
# 194	3	0.0	4	2 1
# 195	2	0.0	4	1 0 0 0 1
# 196	1	0.0	4	0 0 1
# 203	1	0.0	4	1
# 211	1	0.0	4	1
# 213	1	0.0	4	1
# 222	1	0.0	4	0 0 0 0 1
# 223	1	0.0	4	1
# 224	1	0.0	4	1
# 227	1	0.0	4	0 1
# 228	2	0.0	4	0 1 0 0 1
# 229	1	0.0	4	0 0 0 0 1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# This is cutadapt 4.9 with Python 3.9.19
# Command line parameters: --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505155_104_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505155_104_L001_R1_001.fastq.gz
# Processing single-end reads on 1 core ...
# Done           00:00:00        32,366 reads @  15.8 µs/read;   3.80 M reads/minute
# Finished in 0.513 s (15.855 µs/read; 3.78 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                  32,366
# Reads with adapters:                     3,998 (12.4%)
#
# == Read fate breakdown ==
# Reads that were too short:                  54 (0.2%)
# Reads written (passing filters):        32,312 (99.8%)
#
# Total basepairs processed:     5,266,313 bp
# Quality-trimmed:                       0 bp (0.0%)
# Total written (filtered):      4,979,800 bp (94.6%)
#
# === Adapter 1 ===
#
# Sequence: GCATCGATGAAGAACGCAGC; Type: regular 3'; Length: 20; Trimmed: 3998 times
#
# Minimum overlap: 16
# No. of allowed errors:
# 1-4 bp: 0; 5-9 bp: 1; 10-14 bp: 2; 15-19 bp: 3; 20 bp: 4
#
# Bases preceding removed adapters:
#   A: 6.6%
#   C: 85.1%
#   G: 4.4%
#   T: 2.6%
#   none/other: 1.4%
# WARNING:
#     The adapter is preceded by 'C' extremely often.
#     The provided adapter sequence could be incomplete at its 5' end.
#     Ignore this warning when trimming primers.
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 13	5	0.0	2	0 0 0 5
# 14	249	0.0	2	0 0 201 48
# 15	51	0.0	3	0 27 15 9
# 16	4	0.0	3	1 1 2
# 17	9	0.0	3	1 4 2 2
# 18	39	0.0	3	10 7 7 15
# 19	14	0.0	3	8 1 2 1 2
# 20	14	0.0	4	5 4 1 1 3
# 21	17	0.0	4	5 4 5 0 3
# 22	9	0.0	4	1 1 1 3 3
# 23	4	0.0	4	0 0 0 3 1
# 25	7	0.0	4	1 0 1 4 1
# 27	2	0.0	4	1 0 0 0 1
# 28	1	0.0	4	1
# 29	33	0.0	4	16 10 6 0 1
# 30	1	0.0	4	1
# 34	1	0.0	4	1
# 35	2	0.0	4	0 1 0 1
# 36	11	0.0	4	1 1 3 4 2
# 37	126	0.0	4	96 22 4 3 1
# 38	12	0.0	4	4 4 1 3
# 40	7	0.0	4	0 4 2 1
# 41	43	0.0	4	24 7 6 4 2
# 42	14	0.0	4	5 4 1 1 3
# 43	44	0.0	4	20 12 7 4 1
# 44	3	0.0	4	1 1 1
# 45	1	0.0	4	1
# 46	3	0.0	4	0 1 1 0 1
# 47	5	0.0	4	1 1 1 1 1
# 48	14	0.0	4	5 4 3 1 1
# 49	12	0.0	4	5 2 3 0 2
# 50	9	0.0	4	4 1 1 2 1
# 51	5	0.0	4	2 0 2 0 1
# 52	5	0.0	4	3 1 1
# 53	25	0.0	4	11 7 2 5
# 54	6	0.0	4	2 0 2 1 1
# 55	5	0.0	4	1 3 0 0 1
# 56	5	0.0	4	3 1 1
# 57	45	0.0	4	19 14 7 4 1
# 58	20	0.0	4	12 5 2 1
# 59	1	0.0	4	0 0 0 1
# 60	3	0.0	4	0 0 2 1
# 61	4	0.0	4	2 1 1
# 62	928	0.0	4	683 177 52 13 3
# 63	135	0.0	4	107 14 9 3 2
# 64	18	0.0	4	10 6 1 0 1
# 65	11	0.0	4	2 5 0 3 1
# 66	1	0.0	4	1
# 67	2	0.0	4	0 2
# 68	2	0.0	4	0 1 1
# 69	1	0.0	4	0 0 1
# 70	8	0.0	4	4 0 1 1 2
# 71	33	0.0	4	23 6 0 4
# 72	4	0.0	4	0 1 3
# 73	16	0.0	4	5 7 3 0 1
# 74	24	0.0	4	18 4 1 1
# 75	25	0.0	4	13 8 2 1 1
# 76	7	0.0	4	3 2 2
# 77	11	0.0	4	7 3 0 0 1
# 78	9	0.0	4	5 2 1 0 1
# 79	3	0.0	4	2 1
# 80	6	0.0	4	3 3
# 81	8	0.0	4	5 2 0 0 1
# 82	5	0.0	4	4 0 1
# 83	28	0.0	4	17 7 2 0 2
# 84	6	0.0	4	5 1
# 85	195	0.0	4	157 31 7
# 86	962	0.0	4	779 134 37 8 4
# 87	119	0.0	4	100 17 2
# 88	7	0.0	4	6 1
# 89	25	0.0	4	18 5 1 0 1
# 90	7	0.0	4	5 1 1
# 91	1	0.0	4	1
# 92	4	0.0	4	2 0 0 1 1
# 93	5	0.0	4	1 0 1 3
# 94	4	0.0	4	4
# 95	8	0.0	4	7 1
# 96	11	0.0	4	10 1
# 97	12	0.0	4	9 3
# 98	12	0.0	4	9 2 1
# 99	9	0.0	4	7 2
# 100	10	0.0	4	7 2 0 0 1
# 101	16	0.0	4	14 1 0 0 1
# 102	7	0.0	4	6 1
# 103	10	0.0	4	8 0 1 0 1
# 104	15	0.0	4	11 3 0 1
# 105	17	0.0	4	15 1 0 1
# 106	17	0.0	4	14 1 0 2
# 107	14	0.0	4	10 2 0 0 2
# 108	7	0.0	4	6 0 1
# 109	6	0.0	4	4 1 0 1
# 110	12	0.0	4	10 1 1
# 111	10	0.0	4	9 1
# 112	7	0.0	4	5 1 0 0 1
# 113	17	0.0	4	12 3 0 1 1
# 114	7	0.0	4	6 0 0 0 1
# 115	9	0.0	4	9
# 116	11	0.0	4	5 3 0 2 1
# 117	11	0.0	4	8 3
# 118	12	0.0	4	7 4 0 1
# 119	2	0.0	4	1 0 0 1
# 120	10	0.0	4	8 2
# 121	11	0.0	4	9 2
# 122	7	0.0	4	5 2
# 123	7	0.0	4	5 1 0 1
# 124	9	0.0	4	4 3 1 1
# 125	2	0.0	4	1 0 0 1
# 126	3	0.0	4	3
# 127	6	0.0	4	6
# 128	5	0.0	4	1 1 1 2
# 129	2	0.0	4	2
# 130	1	0.0	4	1
# 131	1	0.0	4	1
# 132	2	0.0	4	0 0 2
# 133	5	0.0	4	5
# 134	3	0.0	4	3
# 136	1	0.0	4	1
# 137	7	0.0	4	6 1
# 138	3	0.0	4	1 1 0 0 1
# 139	2	0.0	4	2
# 140	2	0.0	4	1 1
# 141	4	0.0	4	3 1
# 142	4	0.0	4	2 0 0 2
# 143	1	0.0	4	1
# 146	1	0.0	4	1
# 147	3	0.0	4	2 0 1
# 148	8	0.0	4	5 1 0 1 1
# 149	2	0.0	4	1 1
# 150	5	0.0	4	4 0 0 0 1
# 151	2	0.0	4	1 1
# 152	4	0.0	4	3 1
# 153	4	0.0	4	2 1 0 1
# 154	1	0.0	4	1
# 155	5	0.0	4	4 1
# 156	1	0.0	4	1
# 158	5	0.0	4	3 1 0 0 1
# 159	3	0.0	4	2 1
# 160	3	0.0	4	3
# 161	2	0.0	4	1 1
# 162	1	0.0	4	0 1
# 163	2	0.0	4	1 1
# 164	2	0.0	4	2
# 165	3	0.0	4	3
# 166	1	0.0	4	1
# 167	3	0.0	4	2 1
# 169	1	0.0	4	1
# 170	2	0.0	4	2
# 171	1	0.0	4	0 0 0 1
# 173	1	0.0	4	1
# 174	2	0.0	4	2
# 175	1	0.0	4	1
# 176	3	0.0	4	0 1 1 1
# 178	5	0.0	4	4 1
# 179	2	0.0	4	1 0 0 1
# 180	3	0.0	4	3
# 182	2	0.0	4	1 0 0 0 1
# 183	2	0.0	4	1 1
# 184	2	0.0	4	2
# 186	2	0.0	4	1 1
# 187	4	0.0	4	3 1
# 188	1	0.0	4	1
# 189	6	0.0	4	4 2
# 192	2	0.0	4	1 1
# 193	1	0.0	4	0 0 0 0 1
# 195	2	0.0	4	1 0 1
# 196	1	0.0	4	1
# 197	1	0.0	4	1
# 200	1	0.0	4	1
# 201	1	0.0	4	1
# 204	1	0.0	4	0 1
# 206	2	0.0	4	2
# 207	1	0.0	4	1
# 217	1	0.0	4	1
# 219	2	0.0	4	2
# 222	1	0.0	4	1
# 225	2	0.0	4	2
# 228	1	0.0	4	1
#
#
# WARNING:
#     One or more of your adapter sequences may be incomplete.
#     Please see the detailed output above.
# cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505143_92_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505143_92_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505144_93_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505144_93_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505145_94_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505145_94_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505146_95_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505146_95_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505147_96_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505147_96_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505148_97_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505148_97_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505149_98_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505149_98_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505150_99_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505150_99_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505151_100_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505151_100_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505152_101_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505152_101_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505153_102_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505153_102_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505154_103_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505154_103_L001_R1_001.fastq.gz
#
#
# Command: cutadapt --cores 1 --error-rate 0.2 --times 1 --overlap 16 --minimum-length 1 -q 0,0 --quality-base 33 -o /tmp/q2-CasavaOneEightSingleLanePerSampleDirFmt-49dcobb7/SRR10505155_104_L001_R1_001.fastq.gz --adapter GCATCGATGAAGAACGCAGC /tmp/qiime2/jovyan/data/56c8c939-5f46-4211-a8db-43e813d45a05/data/SRR10505155_104_L001_R1_001.fastq.gz
#
# Saved SampleData[SequencesWithQuality] to: data/preprocessing/pundemic_forward_reads_trimmed_QCfiltered_2.qza

# %%
! qiime demux summarize \
    --i-data $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered_2.qza  \
    --o-visualization $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered_2.qzv
# Out:
# Saved Visualization to: data/pundemic_forward_reads_trimmed_QCfiltered_2.qzv

# %%
Visualization.load(f"{data_dir_pre}/pundemic_forward_reads_trimmed_QCfiltered_2.qzv")
# Out:
# <visualization: Visualization uuid: 39b2cb32-ea90-4563-abdf-bd8decffea5e>

# %% [markdown]
# Through this process of filtering we are left with:
#
# 7,977,313 starting reads
#
# 7,792,119 after primer trimming and QC filtering

# %% [markdown]
# # Denoising
# Our sequences originate from the ITS-1 region and were sequenced on an Illumina MiSeq machine. The sequence files contain demultiplexed single-end sequences.
#
# We're using DADA2. It removes chimeras from our demuxed data. The output of applying DADA gives us features which are representative sequences for organisms.

# %% [markdown]
# ### Denoising with trimmed and quality filtered reads

# %%
# Dada2 denoising using truncation length

! qiime dada2 denoise-single \
    --i-demultiplexed-seqs $data_dir_pre/pundemic_forward_reads_trimmed_QCfiltered_2.qza \
    --p-trunc-len 0 \
    --o-table $data_dir/dada/dada2_table_18-11.qza \
    --o-representative-sequences $data_dir/dada/dada2_rep_seq18-11.qza \
    --o-denoising-stats $data_dir/dada/dada2_stats18-11.qza

# %%
! qiime metadata tabulate \
    --m-input-file $data_dir/dada/dada2_stats18-11.qza \
    --o-visualization $data_dir/dada/dada2_stats_18-11.qzv

# %%
Visualization.load(f"{data_dir}/dada/dada2_stats_18-11.qzv")

# %%
! qiime feature-table tabulate-seqs \
    --i-data $data_dir/dada/dada2_rep_seq18-11.qza \
    --o-visualization $data_dir/dada/dada2_rep_seq_18-11.qzv

# %%
Visualization.load(f"{data_dir}/dada/dada2_rep_seq_18-11.qzv")

# %% [markdown]
# We can also visualize the feature table. We will include the metadata file to enrich the table with information on sample groups.

# %%
! qiime feature-table summarize \
    --i-table $data_dir/dada/dada2_table_18-11.qza \
    --m-sample-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/dada/dada2_table_18-11.qzv

# %%
Visualization.load(f"{data_dir}/dada/dada2_table_18-11.qzv")

# %% [markdown]
# After denoising, we are left with 7,113,576 of the 7,792,119 trimmed and QC filtered reads.

# %% [markdown]
# # Classification - training a classifier

# %%
# Download the UNITE v10.0 reference data for “ALL EUKARYOTES” from UNITE using RESCRIPt
! qiime rescript get-unite-data \
    --p-version '10.0' \
    --p-taxon-group 'eukaryotes' \
    --p-cluster-id '99' \
    --p-singletons False \
    --o-taxonomy $data_dir/unite/unite-v10-99-all-euk-taxonomy.qza \
    --o-sequences $data_dir/unite/unite-v10-99-all-euk-sequences.qza \
    --verbose

# %%
# Remove the species hypotheses information
! qiime rescript edit-taxonomy \
    --i-taxonomy $data_dir/unite/unite-v10-99-all-euk-taxonomy.qza \
    --o-edited-taxonomy $data_dir/unite/unite-v10-99-all-euk-taxonomy-no-sh.qza \
    --p-search-strings ';sh__.*' \
    --p-replacement-strings '' \
    --p-use-regex

# %%
# Train NB classifier
! qiime feature-classifier fit-classifier-naive-bayes \
    --i-reference-reads unite-v10-99-all-euk-sequences.qza \
    --i-reference-taxonomy unite-v10-99-all-euk-taxonomy-no-sh.qza \
    --o-classifier unite-v10-99-all-euk-classifier.qza

## have to do this on euler ^^
## upload to euler
scp unite-v10-99-all-euk-sequences.qza ameara@euler.ethz.ch:/cluster/scratch/ameara/apbio2/unite/
scp unite-v10-99-all-euk-taxonomy-no-sh.qza ameara@euler.ethz.ch:/cluster/scratch/ameara/apbio2/unite/
scp dada2_table_18-11.qza ameara@euler.ethz.ch:/cluster/scratch/ameara/apbio2/unite/

sbatch --time=360 --ntasks=1 --mem-per-cpu=128G scripts/train.sh 

# script for training
#!/bin/bash
source ~/miniconda3/etc/profile.d/conda.sh
conda activate q2
DATA="/cluster/scratch/ameara/apbio2/data"
CDATA="/cluster/scratch/ameara/apbio2/unite"

echo "Start training!"

qiime feature-classifier fit-classifier-naive-bayes \
    --i-reference-reads $CDATA/unite-v10-99-all-euk-sequences.qza \
    --i-reference-taxonomy $CDATA/unite-v10-99-all-euk-taxonomy-no-sh.qza \
    --o-classifier $CDATA/unite-v10-99-all-euk-classifier.qza

echo "training done."

# %%
# Retrieve data from euler
scp ameara@euler.ethz.ch:/cluster/scratch/ameara/apbio2/data/taxonomy_trained_18-11.qza .

# %%
# Plot the results
# for data from pretrained classifier
! qiime taxa barplot \
    --i-table $data_dir/dada/dada2_table_18-11.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_trained_18-11.qza \
    --m-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/taxonomy_classification/taxa-barplot_trained_18-11.qzv

# %%
Visualization.load(f"{data_dir}/taxonomy_classification/taxa-barplot_trained_18-11.qzv")

# %% [markdown]
# This was not used in our final analysis, as Blast classification performed better

# %% [markdown]
# # Closed reference clustering

# %%
# Close-reference clustering done on Euler
! qiime vsearch cluster-features-closed-reference \
  --i-table $data_dir/dada/dada2_table_18-11.qza \
  --i-sequences $data_dir/dada/dada2_rep_seq18-11.qza \
  --i-reference-sequences $data_dir/unite_db/unite-v10-99-all-euk-sequences.qza \
  --p-perc-identity 0.90 \
  --o-clustered-table $data_dir/closed_reference_cluster/cr90_feature_table.qza \
  --o-clustered-sequences $data_dir/closed_reference_cluster/cr90_rep_seqs.qza \
  --o-unmatched-sequences $data_dir/closed_reference_cluster/cr90_unmatched_rep_seqs.qza \
  --p-threads 0

# sbatch --time=360 --ntasks=1 --mem-per-cpu=128G scripts/cluster_closed_cr90_18-11.sh

# %%
! qiime feature-table tabulate-seqs \
    --i-data $data_dir/closed_reference_cluster/cr90_rep_seqs.qza \
    --o-visualization $data_dir/closed_reference_cluster/cr90_rep_seqs.qzv

! qiime feature-table summarize \
    --i-table $data_dir/closed_reference_cluster/cr90_feature_table.qza \
    --m-sample-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/closed_reference_cluster/cr90_feature_table.qzv

# %%
Visualization.load(f"{data_dir}/closed_reference_cluster/cr90_rep_seqs.qzv")

# %%
Visualization.load(f"{data_dir}/closed_reference_cluster/cr90_feature_table.qzv")

# %%
# Start classifying via blast

! qiime feature-classifier classify-consensus-blast \
    --i-query $data_dir/closed_reference_cluster/cr90_rep_seqs.qza \
    --i-reference-taxonomy $data_dir/unite_db/unite-v10-99-all-euk-taxonomy.qza \
    --i-reference-reads $data_dir/unite_db/unite-v10-99-all-euk-sequences.qza \
    --p-perc-identity 0.9 \
    --p-query-cov 0.7 \
    --p-num-threads 0 \
    --o-classification $data_dir/taxonomy_classification/taxonomy_blast_18-11.qza  \
    --o-search-results $data_dir/taxonomy_classification/top_hits_blast_18-11.qza

# %%
# Plot the results
# for data from blast classification from clustering
! qiime taxa barplot \
    --i-table $data_dir/closed_reference_cluster/cr90_feature_table.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_blast_18-11.qza \
    --m-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/taxonomy_classification/taxa-barplot_18-11_blast.qzv

# %%
Visualization.load(f"{data_dir}/taxonomy_classification/taxa-barplot_18-11_blast.qzv")

# %%
# Filter out non fungal data
! qiime taxa filter-table \
    --i-table $data_dir/closed_reference_cluster/cr90_feature_table.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_blast_18-11.qza \
    --p-exclude k__Viridiplantae,k__Stramenopila,k__Metazoa\
    --p-include c__ \
    --o-filtered-table $data_dir/closed_reference_cluster/table-filtered.qza

! qiime taxa filter-seqs \
    --i-sequences $data_dir/closed_reference_cluster/cr90_rep_seqs.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_blast_18-11.qza \
    --p-exclude k__Viridiplantae,k__Stramenopila,k__Metazoa\
    --p-include c__ \
    --o-filtered-sequences $data_dir/closed_reference_cluster/rep-seqs-filtered.qza

# %%
! qiime feature-table tabulate-seqs \
    --i-data $data_dir/closed_reference_cluster/rep-seqs-filtered.qza \
    --o-visualization $data_dir/closed_reference_cluster/rep_seqs_filtered.qzv

! qiime feature-table summarize \
    --i-table $data_dir/closed_reference_cluster/table-filtered.qza \
    --m-sample-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/closed_reference_cluster/table-filtered.qzv

# %%
Visualization.load(f"{data_dir}/closed_reference_cluster/rep_seqs_filtered.qzv")

# %%
Visualization.load(f"{data_dir}/closed_reference_cluster/table-filtered.qzv")

# %%
# Plot the results
# for data from blast classification from clustering
! qiime taxa barplot \
    --i-table $data_dir/closed_reference_cluster/table-filtered.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_blast_18-11.qza \
    --m-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/taxonomy_classification/taxa-barplot_blast_filtered.qzv

# %%
Visualization.load(f"{data_dir}/taxonomy_classification/taxa-barplot_blast_filtered.qzv")
# Out:
# <visualization: Visualization uuid: b4159564-32ef-4653-a735-90d5c625fa77>

# %% [markdown]
# # Classifying with pretrained
#
# Attempted using a classifier pre trained on the Unite DB for our data

# %%
# Retrieve classification from pretrained from unite_ver10_99_all
scp ameara@euler.ethz.ch:/cluster/scratch/ameara/apbio2/data/taxonomy_18-11.qza .

# %%
# Plot the results
# for data from pretrained classifier
! qiime taxa barplot \
    --i-table $data_dir/dada/dada2_table_18-11.qza \
    --i-taxonomy $data_dir/taxonomy_classification/taxonomy_pretrained_18-11.qza \
    --m-metadata-file $data_dir/pundemic_metadata.tsv \
    --o-visualization $data_dir/taxonomy_classification/taxa-barplot_18-11_pretrained.qzv

# %%
Visualization.load(f"{data_dir}/taxonomy_classification/taxa-barplot_18-11_pretrained.qzv")

# %% [markdown]
# This was not used in our final analysis, as Blast classification performed better
